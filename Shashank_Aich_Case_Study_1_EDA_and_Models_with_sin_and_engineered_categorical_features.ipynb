# %% [markdown]
# # Predicting Telephonic Marketing Outcome for Bank Term Deposit

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Data-Set-Information:" data-toc-modified-id="Data-Set-Information:-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Data Set Information:</a></span></li><li><span><a href="#Attribute-Information:" data-toc-modified-id="Attribute-Information:-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Attribute Information:</a></span><ul class="toc-item"><li><span><a href="#Input-variables:" data-toc-modified-id="Input-variables:-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Input variables:</a></span></li></ul></li><li><span><a href="#Reading-Data" data-toc-modified-id="Reading-Data-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Reading Data</a></span></li><li><span><a href="#Utility-Functions" data-toc-modified-id="Utility-Functions-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Utility Functions</a></span></li><li><span><a href="#Exploratory-Data-Analysis" data-toc-modified-id="Exploratory-Data-Analysis-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Exploratory Data Analysis</a></span><ul class="toc-item"><li><span><a href="#Exploratory-Data-Analysis-on-Neumeral-Features" data-toc-modified-id="Exploratory-Data-Analysis-on-Neumeral-Features-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Exploratory Data Analysis on Neumeral Features</a></span><ul class="toc-item"><li><span><a href="#age" data-toc-modified-id="age-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>age</a></span><ul class="toc-item"><li><span><a href="#sin(age)" data-toc-modified-id="sin(age)-5.1.1.1"><span class="toc-item-num">5.1.1.1&nbsp;&nbsp;</span>sin(age)</a></span></li></ul></li><li><span><a href="#duration" data-toc-modified-id="duration-5.1.2"><span class="toc-item-num">5.1.2&nbsp;&nbsp;</span>duration</a></span><ul class="toc-item"><li><span><a href="#sin(duration)" data-toc-modified-id="sin(duration)-5.1.2.1"><span class="toc-item-num">5.1.2.1&nbsp;&nbsp;</span>sin(duration)</a></span></li></ul></li><li><span><a href="#campaign" data-toc-modified-id="campaign-5.1.3"><span class="toc-item-num">5.1.3&nbsp;&nbsp;</span>campaign</a></span><ul class="toc-item"><li><span><a href="#sin(campaign)" data-toc-modified-id="sin(campaign)-5.1.3.1"><span class="toc-item-num">5.1.3.1&nbsp;&nbsp;</span>sin(campaign)</a></span></li></ul></li><li><span><a href="#pdays" data-toc-modified-id="pdays-5.1.4"><span class="toc-item-num">5.1.4&nbsp;&nbsp;</span>pdays</a></span><ul class="toc-item"><li><span><a href="#sin(pdays)" data-toc-modified-id="sin(pdays)-5.1.4.1"><span class="toc-item-num">5.1.4.1&nbsp;&nbsp;</span>sin(pdays)</a></span></li></ul></li><li><span><a href="#previous" data-toc-modified-id="previous-5.1.5"><span class="toc-item-num">5.1.5&nbsp;&nbsp;</span>previous</a></span><ul class="toc-item"><li><span><a href="#sin(previous)" data-toc-modified-id="sin(previous)-5.1.5.1"><span class="toc-item-num">5.1.5.1&nbsp;&nbsp;</span>sin(previous)</a></span></li></ul></li><li><span><a href="#emp.var.rate" data-toc-modified-id="emp.var.rate-5.1.6"><span class="toc-item-num">5.1.6&nbsp;&nbsp;</span>emp.var.rate</a></span><ul class="toc-item"><li><span><a href="#sin(emp.var.rate)" data-toc-modified-id="sin(emp.var.rate)-5.1.6.1"><span class="toc-item-num">5.1.6.1&nbsp;&nbsp;</span>sin(emp.var.rate)</a></span></li></ul></li><li><span><a href="#cons.price.idx" data-toc-modified-id="cons.price.idx-5.1.7"><span class="toc-item-num">5.1.7&nbsp;&nbsp;</span>cons.price.idx</a></span><ul class="toc-item"><li><span><a href="#sin(cons.price.idx)" data-toc-modified-id="sin(cons.price.idx)-5.1.7.1"><span class="toc-item-num">5.1.7.1&nbsp;&nbsp;</span>sin(cons.price.idx)</a></span></li></ul></li><li><span><a href="#cons.conf.idx" data-toc-modified-id="cons.conf.idx-5.1.8"><span class="toc-item-num">5.1.8&nbsp;&nbsp;</span>cons.conf.idx</a></span><ul class="toc-item"><li><span><a href="#sin(cons.conf.idx)" data-toc-modified-id="sin(cons.conf.idx)-5.1.8.1"><span class="toc-item-num">5.1.8.1&nbsp;&nbsp;</span>sin(cons.conf.idx)</a></span></li></ul></li><li><span><a href="#euribor3m" data-toc-modified-id="euribor3m-5.1.9"><span class="toc-item-num">5.1.9&nbsp;&nbsp;</span>euribor3m</a></span><ul class="toc-item"><li><span><a href="#sin(euribor3m)" data-toc-modified-id="sin(euribor3m)-5.1.9.1"><span class="toc-item-num">5.1.9.1&nbsp;&nbsp;</span>sin(euribor3m)</a></span></li></ul></li><li><span><a href="#nr.employed" data-toc-modified-id="nr.employed-5.1.10"><span class="toc-item-num">5.1.10&nbsp;&nbsp;</span>nr.employed</a></span><ul class="toc-item"><li><span><a href="#sin(nr.employed)" data-toc-modified-id="sin(nr.employed)-5.1.10.1"><span class="toc-item-num">5.1.10.1&nbsp;&nbsp;</span>sin(nr.employed)</a></span></li></ul></li></ul></li><li><span><a href="#Important-Numerical-Features-after-performing-EDA-on-Numerical-Features:" data-toc-modified-id="Important-Numerical-Features-after-performing-EDA-on-Numerical-Features:-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Important Numerical Features after performing EDA on Numerical Features:</a></span></li><li><span><a href="#Exploratory-Data-Analysis-on-Categorical-Features" data-toc-modified-id="Exploratory-Data-Analysis-on-Categorical-Features-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Exploratory Data Analysis on Categorical Features</a></span><ul class="toc-item"><li><span><a href="#job" data-toc-modified-id="job-5.3.1"><span class="toc-item-num">5.3.1&nbsp;&nbsp;</span>job</a></span></li><li><span><a href="#marital" data-toc-modified-id="marital-5.3.2"><span class="toc-item-num">5.3.2&nbsp;&nbsp;</span>marital</a></span></li><li><span><a href="#education" data-toc-modified-id="education-5.3.3"><span class="toc-item-num">5.3.3&nbsp;&nbsp;</span>education</a></span></li><li><span><a href="#default" data-toc-modified-id="default-5.3.4"><span class="toc-item-num">5.3.4&nbsp;&nbsp;</span>default</a></span></li><li><span><a href="#housing" data-toc-modified-id="housing-5.3.5"><span class="toc-item-num">5.3.5&nbsp;&nbsp;</span>housing</a></span></li><li><span><a href="#loan" data-toc-modified-id="loan-5.3.6"><span class="toc-item-num">5.3.6&nbsp;&nbsp;</span>loan</a></span></li><li><span><a href="#contact" data-toc-modified-id="contact-5.3.7"><span class="toc-item-num">5.3.7&nbsp;&nbsp;</span>contact</a></span></li><li><span><a href="#month" data-toc-modified-id="month-5.3.8"><span class="toc-item-num">5.3.8&nbsp;&nbsp;</span>month</a></span></li><li><span><a href="#day_of_week" data-toc-modified-id="day_of_week-5.3.9"><span class="toc-item-num">5.3.9&nbsp;&nbsp;</span>day_of_week</a></span></li><li><span><a href="#poutcome" data-toc-modified-id="poutcome-5.3.10"><span class="toc-item-num">5.3.10&nbsp;&nbsp;</span>poutcome</a></span></li></ul></li></ul></li><li><span><a href="#Feature-Engineering" data-toc-modified-id="Feature-Engineering-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Feature Engineering</a></span><ul class="toc-item"><li><span><a href="#Geting-Thresholds-from-Numerical-Features" data-toc-modified-id="Geting-Thresholds-from-Numerical-Features-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Geting Thresholds from Numerical Features</a></span><ul class="toc-item"><li><span><a href="#age" data-toc-modified-id="age-6.1.1"><span class="toc-item-num">6.1.1&nbsp;&nbsp;</span>age</a></span></li><li><span><a href="#duration" data-toc-modified-id="duration-6.1.2"><span class="toc-item-num">6.1.2&nbsp;&nbsp;</span>duration</a></span></li><li><span><a href="#campaign" data-toc-modified-id="campaign-6.1.3"><span class="toc-item-num">6.1.3&nbsp;&nbsp;</span>campaign</a></span></li><li><span><a href="#pdays" data-toc-modified-id="pdays-6.1.4"><span class="toc-item-num">6.1.4&nbsp;&nbsp;</span>pdays</a></span></li><li><span><a href="#previous" data-toc-modified-id="previous-6.1.5"><span class="toc-item-num">6.1.5&nbsp;&nbsp;</span>previous</a></span></li><li><span><a href="#emp.var.rate" data-toc-modified-id="emp.var.rate-6.1.6"><span class="toc-item-num">6.1.6&nbsp;&nbsp;</span>emp.var.rate</a></span></li><li><span><a href="#cons.price.idx" data-toc-modified-id="cons.price.idx-6.1.7"><span class="toc-item-num">6.1.7&nbsp;&nbsp;</span>cons.price.idx</a></span></li><li><span><a href="#cons.conf.idx" data-toc-modified-id="cons.conf.idx-6.1.8"><span class="toc-item-num">6.1.8&nbsp;&nbsp;</span>cons.conf.idx</a></span></li><li><span><a href="#euribor3m" data-toc-modified-id="euribor3m-6.1.9"><span class="toc-item-num">6.1.9&nbsp;&nbsp;</span>euribor3m</a></span></li><li><span><a href="#nr.employed" data-toc-modified-id="nr.employed-6.1.10"><span class="toc-item-num">6.1.10&nbsp;&nbsp;</span>nr.employed</a></span></li></ul></li></ul></li><li><span><a href="#Data-Preparation-for-ML-Models" data-toc-modified-id="Data-Preparation-for-ML-Models-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Data Preparation for ML Models</a></span><ul class="toc-item"><li><span><a href="#Lets-do-a-Train-Test-Split" data-toc-modified-id="Lets-do-a-Train-Test-Split-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Lets do a Train-Test Split</a></span></li><li><span><a href="#Standardizing-the-Features-in-the-Train,-CV-and-Test-Datasets" data-toc-modified-id="Standardizing-the-Features-in-the-Train,-CV-and-Test-Datasets-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Standardizing the Features in the Train, CV and Test Datasets</a></span></li></ul></li><li><span><a href="#Converting-Real-World-Problem-to-ML-Problem" data-toc-modified-id="Converting-Real-World-Problem-to-ML-Problem-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Converting Real World Problem to ML Problem</a></span></li><li><span><a href="#Machine-Learning-Models" data-toc-modified-id="Machine-Learning-Models-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Machine Learning Models</a></span><ul class="toc-item"><li><span><a href="#Logistic-Regression" data-toc-modified-id="Logistic-Regression-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Logistic Regression</a></span></li><li><span><a href="#Naive-Bayes" data-toc-modified-id="Naive-Bayes-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>Naive Bayes</a></span></li><li><span><a href="#Linear-SVM" data-toc-modified-id="Linear-SVM-9.3"><span class="toc-item-num">9.3&nbsp;&nbsp;</span>Linear SVM</a></span></li><li><span><a href="#Decision-Tree" data-toc-modified-id="Decision-Tree-9.4"><span class="toc-item-num">9.4&nbsp;&nbsp;</span>Decision Tree</a></span></li><li><span><a href="#Random-Forest" data-toc-modified-id="Random-Forest-9.5"><span class="toc-item-num">9.5&nbsp;&nbsp;</span>Random Forest</a></span></li><li><span><a href="#XGBoost" data-toc-modified-id="XGBoost-9.6"><span class="toc-item-num">9.6&nbsp;&nbsp;</span>XGBoost</a></span></li><li><span><a href="#Simple-Neural-Network(With-1-layer)" data-toc-modified-id="Simple-Neural-Network(With-1-layer)-9.7"><span class="toc-item-num">9.7&nbsp;&nbsp;</span>Simple Neural Network(With 1 layer)</a></span></li><li><span><a href="#Stacking-Classifier" data-toc-modified-id="Stacking-Classifier-9.8"><span class="toc-item-num">9.8&nbsp;&nbsp;</span>Stacking Classifier</a></span></li><li><span><a href="#Voting-Classifier" data-toc-modified-id="Voting-Classifier-9.9"><span class="toc-item-num">9.9&nbsp;&nbsp;</span>Voting Classifier</a></span></li></ul></li><li><span><a href="#Conclusions" data-toc-modified-id="Conclusions-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Conclusions</a></span></li><li><span><a href="#References" data-toc-modified-id="References-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>References</a></span></li></ul></div>

# %% [markdown]
# ## Data Set Information:

# %% [markdown]
# The data is related with direct marketing campaigns of a Portuguese banking institution. The marketing campaigns were based on phone calls. Often, more than one contact to the same client was required, in order to access if the product (bank term deposit) would be ('yes') or not ('no') subscribed.
#
# There are four datasets:
# 1. bank-additional-full.csv with all examples (41188) and 20 inputs, ordered by date (from May 2008 to November 2010), very close to the data analyzed in [Moro et al., 2014]
# 2. bank-additional.csv with 10% of the examples (4119), randomly selected from 1), and 20 inputs.
# 3. bank-full.csv with all examples and 17 inputs, ordered by date (older version of this dataset with less inputs).
# 4. bank.csv with 10% of the examples and 17 inputs, randomly selected from 3 (older version of this dataset with less inputs).
# The smallest datasets are provided to test more computationally demanding machine learning algorithms (e.g., SVM).
#
# The classification goal is to predict if the client will subscribe (yes/no) a term deposit (variable y).
#
# __In this Case Study we will take the new Dataset bank-additional-full.csv__

# %% [markdown]
# ## Attribute Information:

# %% [markdown]
# ### Input variables:
#
# __bank_additional client data:__
#    1. age (numeric)
#    2. job : type of job (categorical: "admin.","blue-collar","entrepreneur","housemaid","management","retired","self-employed","services","student","technician","unemployed","unknown")
#    3. marital : marital status (categorical: "divorced","married","single","unknown"; note: "divorced" means divorced or widowed)
#    4. education (categorical: "basic.4y","basic.6y","basic.9y","high.school","illiterate","professional.course","university.degree","unknown")
#    5. default: has credit in default? (categorical: "no","yes","unknown")
#    6. housing: has housing loan? (categorical: "no","yes","unknown")
#    7. loan: has personal loan? (categorical: "no","yes","unknown")
#
# __related with the last contact of the current campaign:__
#    8. contact: contact communication type (categorical: "cellular","telephone")
#    9. month: last contact month of year (categorical: "jan", "feb", "mar", ..., "nov", "dec")
#    10. day_of_week: last contact day of the week (categorical: "mon","tue","wed","thu","fri")
#    11. duration: last contact duration, in seconds (numeric). Important note:  this attribute highly affects the output target (e.g., if duration=0 then y="no"). Yet, the duration is not known before a call is performed. Also, after the end of the call y is obviously known. Thus, this input should only be included for benchmark purposes and should be discarded if the intention is to have a realistic predictive model.
#
# __other attributes:__
#    12. campaign: number of contacts performed during this campaign and for this client (numeric, includes last contact)
#    13. pdays: number of days that passed by after the client was last contacted from a previous campaign (numeric; 999 means client was not previously contacted)
#    14. previous: number of contacts performed before this campaign and for this client (numeric)
#    15. poutcome: outcome of the previous marketing campaign (categorical: "failure","nonexistent","success")
#
# __social and economic context attributes:__
#    16. emp.var.rate: employment variation rate - quarterly indicator (numeric)
#    17. cons.price.idx: consumer price index - monthly indicator (numeric)
#    18. cons.conf.idx: consumer confidence index - monthly indicator (numeric)
#    19. euribor3m: euribor 3 month rate - daily indicator (numeric)
#    20. nr.employed: number of employees - quarterly indicator (numeric)
#
# __Output variable (desired target):__
#    21. y - has the client subscribed a term deposit? (binary: "yes","no")
#
# __Missing Attribute Values: There are several missing values in some categorical attributes, all coded with the "unknown" label. These missing values can be treated as a possible class label or using deletion or imputation techniques.__

# %% [markdown]
# ## Reading Data

# %%
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import itertools
from itertools import combinations
import random
from scipy import sparse
from scipy.sparse import vstack

import xgboost as xgb

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import StandardScaler


from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import log_loss
from sklearn.metrics import roc_curve
from sklearn.metrics import confusion_matrix

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
from sklearn import tree
from sklearn.linear_model import SGDClassifier
from sklearn.calibration import CalibratedClassifierCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB

# %%
#reading bank_additional.csv
df = pd.read_csv('bank-additional-full.csv', sep=';')
print('df.csv shape', df.shape)
df.columns
# Out:
# df.csv shape (41188, 21)
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
df.describe()
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406    258.285010      2.567593    962.475454      0.172963
# std       10.42125    259.279249      2.770014    186.910907      0.494901
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41188.000000    41188.000000   41188.000000  41188.000000  41188.000000
# mean       0.081886       93.575664     -40.502600      3.621291   5167.035911
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
# age               41188 non-null int64
# job               41188 non-null object
# marital           41188 non-null object
# education         41188 non-null object
# default           41188 non-null object
# housing           41188 non-null object
# loan              41188 non-null object
# contact           41188 non-null object
# month             41188 non-null object
# day_of_week       41188 non-null object
# duration          41188 non-null int64
# campaign          41188 non-null int64
# pdays             41188 non-null int64
# previous          41188 non-null int64
# poutcome          41188 non-null object
# emp.var.rate      41188 non-null float64
# cons.price.idx    41188 non-null float64
# cons.conf.idx     41188 non-null float64
# euribor3m         41188 non-null float64
# nr.employed       41188 non-null float64
# y                 41188 non-null object
# ...

# %%
#Lets look at the number of positive and negative points
df['y'].value_counts()
# Out:
# no     36548
# yes     4640
# Name: y, dtype: int64

# %%
n = 36548 / (36548 + 4640)

y = 4640 / (36548 + 4640)

print(n, y)

data = df
# Out:
# 0.8873458288821987 0.11265417111780131

# %%
# check for duplicate values
print("No of Duplicates in dataset:  ",data.duplicated().sum())
# Out:
# No of Duplicates in dataset:   12

# %%
# drop the duplicates
data.drop_duplicates(inplace=True)

# %% [markdown]
# __The Dataset has 11.27% positive points and 88.73% negative points__

# %% [markdown]
# __There are Missing values in the dataset in the Categorical variables wherein they are encoded as 'unknown'__

# %% [markdown]
# ## Utility Functions

# %%
#function that will return the sine of the feature
def return_sin(x):
    return(np.sin(x))

# %%
#This function will take a list of features and Return the combination of 2 attributes ie nC2 
#wherein n = length of the list and the features will be used for ploting pairplots
def return_nc2(x):
    com = combinations(x, 2)
    return com

# %%
#This function will plot the scatter plots given an array of features and the data
def plotscatter(d, f):
    #get the combinations of the features
    f2 = list(return_nc2(f))
    #get length of combination
    n = len(f2)
    #initialize the 
    fig = [random.random() for z in range(45)]
    axes = [random.random() for z in range(45)]
    #plot all subplots
    for i in range(0, n):
        #plotting the scatterplot
        fig[i], axes[i] = plt.subplots(figsize=(20, 10))
        sns.scatterplot(x=f2[i][0], y=f2[i][1], hue='y', data=d, ax=axes[i])

# %%
#These functions will convert the numerical data to categorical data
#pdays, cons.price.idx, cons.conf.idx, nr.employed


#convert pdays to pdays_cat
def convert_pdays_cat(x):
    #threshold=512.5 if t<=512.5 then pdays_cat_yes else pdays_cat_no
    x['pdays_cat'] = np.where(x['pdays'] <= 513, 'pdays_cat_yes',
                              'pdays_cat_no')


#convert cons.price.idx to cons.price.idx_cat
def convert_cons_price_idx_cat(x):
    #threshold=92.868 if t<=92.868 then cons_price_idx_cat_yes else cons_price_idx_cat_no
    x['cons.price.idx_cat'] = np.where(x['cons.price.idx'] <= 92.868,
                                       'cons_price_idx_yes',
                                       'cons_price_idx_no')


#convert cons.conf.idx to cons.conf.idx_cat
def convert_cons_conf_idx_cat(x):
    #threshold = -35.45 if t<=-35.45 then cons_conf_idx_cat_no else cons_conf_idx_cat_yes
    x['cons.conf.idx_cat'] = np.where(x['cons.conf.idx'] <= -35.45,
                                      'cons_conf_idx_cat_no',
                                      'cons_conf_idx_cat_yes')


#convert nr.employed to nr.employed_cat
def convert_nr_employed_cat(x):
    #threshold=5087.65 if t<=5087.65 then nr_employed_cat_yes else nr_employed_cat_no
    x['nr.employed_cat'] = np.where(x['nr.employed'] <= 5087.65,
                                    'nr_employed_cat_yes',
                                    'nr_employed_cat_no')

# %%
#Now we need to add the engineered features to the cv and the test datasets as well
#hence we create a function for doing the same
def add_features(x_data):
    #add y label to the data
    y_label = x_data['y']  #get y label
    le = LabelEncoder()
    output = le.fit_transform(y_label)  #transform the y label to 0/1 form
    x_data['output'] = output

    #remove the y label and output label
    x_data.drop(['y'], axis=1, inplace=True)
    y_data = x_data['output']
    x_data.drop(['output'], axis=1, inplace=True)

    #Add sine features to the dataset
    fets = [
        'age', 'duration', 'campaign', 'pdays', 'previous', 'emp.var.rate',
        'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed'
    ]  #Features for which sine functions will be added
    for f in fets:
        #get the sine feature for the feature f
        tmp_sin = return_sin(x_data[f].values)
        #create a str name f + '_sin' as the feature_name
        f_name = f + '_sin'
        #add sin feature to the data
        x_data[f_name] = tmp_sin

    #convert selected numerical data to categorical data based on the EDA
    convert_pdays_cat(x_data)
    convert_cons_price_idx_cat(x_data)
    convert_cons_conf_idx_cat(x_data)
    convert_nr_employed_cat(x_data)
    return y_data

# %%
# This function plots the confusion matrices given y_i, y_i_hat.
def plot_confusion_matrix(test_y, predict_y):
    C = confusion_matrix(test_y, predict_y)
    # C = 9,9 matrix, each cell (i,j) represents number of points of class i are predicted class j
    
    A =(((C.T)/(C.sum(axis=1))).T)
    #divid each element of the confusion matrix with the sum of elements in that column
    
    # C = [[1, 2],
    #     [3, 4]]
    # C.T = [[1, 3],
    #        [2, 4]]
    # C.sum(axis = 1)  axis=0 corresonds to columns and axis=1 corresponds to rows in two diamensional array
    # C.sum(axix =1) = [[3, 7]]
    # ((C.T)/(C.sum(axis=1))) = [[1/3, 3/7]
    #                           [2/3, 4/7]]

    # ((C.T)/(C.sum(axis=1))).T = [[1/3, 2/3]
    #                           [3/7, 4/7]]
    # sum of row elements = 1
    
    B =(C/C.sum(axis=0))
    #divid each element of the confusion matrix with the sum of elements in that row
    # C = [[1, 2],
    #     [3, 4]]
    # C.sum(axis = 0)  axis=0 corresonds to columns and axis=1 corresponds to rows in two diamensional array
    # C.sum(axix =0) = [[4, 6]]
    # (C/C.sum(axis=0)) = [[1/4, 2/6],
    #                      [3/4, 4/6]] 
    plt.figure(figsize=(20,4))
    
    labels = [0,1]
    # representing A in heatmap format
    cmap=sns.light_palette("blue")
    plt.subplot(1, 3, 1)
    sns.heatmap(C, annot=True, cmap=cmap, fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.title("Confusion matrix")
    
    plt.subplot(1, 3, 2)
    sns.heatmap(B, annot=True, cmap=cmap, fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.title("Precision matrix")
    
    plt.subplot(1, 3, 3)
    # representing B in heatmap format
    sns.heatmap(A, annot=True, cmap=cmap, fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.title("Recall matrix")
    
    plt.show()

# %%
#function to find maximum auc score and the parameters from the given numpy array
def get_max_auc(arr):
    max_auc = 0
    k = 0
    d = 0
    for a in arr:
        if max_auc < a[2]:
            max_auc = a[2]
            k = a[0]
            d = a[1]
    return max_auc, k, d

# %%
#function to find minimum loss and the parameters from the given numpy array
def get_min_loss(arr):
    min_loss = 99999990
    k = 0
    d = 0
    for a in arr:
        if min_loss > a[2]:
            min_loss = a[2]
            k = a[0]
            d = a[1]
    return min_loss, k, d

# %%
#function to find maximum F1 score and the parameters from the given numpy array
def get_max_F1(arr):
    max_F1 = 0
    k = 0
    d = 0
    for a in arr:
        if max_F1 < a[2]:
            max_F1 = a[2]
            k = a[0]
            d = a[1]
    return max_F1, k, d

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# __In the Dataset There are 20 Attributes and 10 Attributes are neumerical while another 10 are categorical in nature__

# %% [markdown]
# __Numerical Features__
# - age
# - duration
# - campaign
# - pdays
# - previous
# - emp.var.rate
# - cons.price.idx
# - cons.conf.idx
# - euribor3m
# - nr.employed
#
# __Categorical Features__
#
# - job
# - marital
# - education
# - default
# - housing
# - loan
# - contact
# - month
# - day_of_week
# - poutcome

# %% [markdown]
# __In the EDA lets first take the Neumeral Features__

# %% [markdown]
# ### Exploratory Data Analysis on Neumeral Features

# %% [markdown]
# __Numerical Features__
# - age
# - duration
# - campaign
# - pdays
# - previous
# - emp.var.rate
# - cons.price.idx
# - cons.conf.idx
# - euribor3m
# - nr.employed

# %% [markdown]
# __In this Analysis we will als consider some simple Sine of features for analysis on our Neumeric Attributes__

# %% [markdown]
# #### age

# %%
z = 'age'

# %%
data[z].describe()
# Out:
# count    41176.00000
# mean        40.02380
# std         10.42068
# min         17.00000
# 25%         32.00000
# 50%         38.00000
# 75%         47.00000
# max         98.00000
# Name: age, dtype: float64

# %%
sns.set()
np.random.seed(0)
fig = plt.figure(figsize=(15, 10))
tmp_y = data[z][data['y'] == 'yes']
tmp_n = data[z][data['y'] == 'no']
sns.kdeplot(tmp_y, color='g', label='yes', shade=True)
sns.kdeplot(tmp_n, color='r', label='no', shade=True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(9, 7))
sns.violinplot(ax=ax, y=data[z], x=data["y"])

# %% [markdown]
# __From the above two plots we can say that people above 60 have higher Probablity of responding positively to the Marketing Campaign__

# %% [markdown]
# ##### sin(age)

# %%
z_sin = 'age_sin'

# %%
#get sine of feature and add it to the dataframe
tmp_sin = return_sin(data[z].values)
data[z_sin] = tmp_sin
data[z_sin].describe()
# Out:
# count    41176.000000
# mean        -0.003195
# std          0.708309
# min         -0.999755
# 25%         -0.663634
# 50%          0.017702
# 75%          0.670229
# max          0.999912
# Name: age_sin, dtype: float64

# %%
sns.set()
np.random.seed(0)
fig = plt.figure(figsize=(15, 10))
tmp_y = data[z_sin][data['y'] == 'yes']
tmp_n = data[z_sin][data['y'] == 'no']
sns.kdeplot(tmp_y, color='g', label ='yes',shade=True)
sns.kdeplot(tmp_n, color='r', label ='no',shade=True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(9, 7))
sns.violinplot(ax=ax, y=data[z_sin], x=data["y"])

# %% [markdown]
# __The Sine curve of age has higher Peaks than that that of the positive curve also a point which has sin(age)=0 is more probable to be apositive point while point that has sin(age) = +1/-1 is more probable to be a negative point__

# %% [markdown]
# #### duration

# %%
z = 'duration'

# %%
data[z].describe()
# Out:
# count    41176.000000
# mean       258.315815
# std        259.305321
# min          0.000000
# 25%        102.000000
# 50%        180.000000
# 75%        319.000000
# max       4918.000000
# Name: duration, dtype: float64

# %%
sns.set()
np.random.seed(0)
fig = plt.figure(figsize=(15, 10))
tmp_y = data[z][data['y'] == 'yes']
tmp_n = data[z][data['y'] == 'no']
sns.kdeplot(tmp_y, color='g', label ='yes',shade=True)
sns.kdeplot(tmp_n, color='r', label ='no',shade=True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(9, 7))
sns.violinplot(ax=ax, y=data[z], x=data["y"])

# %% [markdown]
# __From the above two plots we can say that if the duration is less ie if the person has a convertation for a short time span on the telephone respond negatively to the Marketing Campaign__

# %% [markdown]
# ##### sin(duration)

# %%
z_sin = 'duration_sin'

# %%
#get sine of feature and add it to the dataframe
tmp_sin = return_sin(data[z].values)
data[z_sin] = tmp_sin
data[z_sin].describe()
# Out:
# count    41176.000000
# mean         0.000732
# std          0.707175
# min         -0.999991
# 25%         -0.702408
# 50%         -0.008851
# 75%          0.708659
# max          0.999990
# Name: duration_sin, dtype: float64

# %%
sns.set()
np.random.seed(0)
fig = plt.figure(figsize=(15, 10))
tmp_y = data[z_sin][data['y'] == 'yes']
tmp_n = data[z_sin][data['y'] == 'no']
sns.kdeplot(tmp_y, color='g', label ='yes',shade=True)
sns.kdeplot(tmp_n, color='r', label ='no',shade=True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(9, 7))
sns.violinplot(ax=ax, y=data[z_sin], x=data["y"])

# %% [markdown]
# __The Sine curve of duration does not say much about the outcome of the campaign except we see that the probablity of a person responding negatively is higher__

# %% [markdown]
# #### campaign

# %%
z = 'campaign'

# %%
data[z].describe()
# Out:
# count    41176.000000
# mean         2.567879
# std          2.770318
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         56.000000
# Name: campaign, dtype: float64

# %%
sns.set()
np.random.seed(0)
fig = plt.figure(figsize=(15, 10))
tmp_y = data[z][data['y'] == 'yes']
tmp_n = data[z][data['y'] == 'no']
sns.kdeplot(tmp_y, color='g', label ='yes',shade=True)
sns.kdeplot(tmp_n, color='r', label ='no',shade=True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(9, 7))
sns.violinplot(ax=ax, y=data[z], x=data["y"])

# %% [markdown]
# __From the above two plots we can say that people who were contacted less have higher Probablity of responding positively to the Marketing Campaign__

# %% [markdown]
# ##### sin(campaign)

# %%
z_sin = 'campaign_sin'

# %%
#get sine of feature and add it to the dataframe
tmp_sin = return_sin(data[z].values)
data[z_sin] = tmp_sin
data[z_sin].describe()
# Out:
# count    41176.000000
# mean         0.534825
# std          0.580945
# min         -0.999990
# 25%          0.141120
# 50%          0.841471
# 75%          0.909297
# max          0.999912
# Name: campaign_sin, dtype: float64

# %%
sns.set()
np.random.seed(0)
fig = plt.figure(figsize=(15, 10))
tmp_y = data[z_sin][data['y'] == 'yes']
tmp_n = data[z_sin][data['y'] == 'no']
sns.kdeplot(tmp_y, color='g', label ='yes',shade=True)
sns.kdeplot(tmp_n, color='r', label ='no',shade=True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(9, 7))
sns.violinplot(ax=ax, y=data[z_sin], x=data["y"])

# %% [markdown]
# __The Sine curve of campaign has higher Peaks for positive data at some values making it very Important__

# %% [markdown]
# #### pdays

# %%
z = 'pdays'

# %%
data[z].describe()
# Out:
# count    41176.000000
# mean       962.464810
# std        186.937102
# min          0.000000
# 25%        999.000000
# 50%        999.000000
# 75%        999.000000
# max        999.000000
# Name: pdays, dtype: float64

# %%
sns.set()
np.random.seed(0)
fig = plt.figure(figsize=(15, 10))
tmp_y = data[z][data['y'] == 'yes']
tmp_n = data[z][data['y'] == 'no']
sns.kdeplot(tmp_y, color='g', label ='yes',shade=True)
sns.kdeplot(tmp_n, color='r', label ='no',shade=True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(9, 7))
sns.violinplot(ax=ax, y=data[z], x=data["y"])

# %% [markdown]
# __From the two Plots we can say that pdays is not an important feature__

# %% [markdown]
# ##### sin(pdays)

# %%
z_sin = 'pdays_sin'

# %%
#get sine of feature and add it to the dataframe
tmp_sin = return_sin(data[z].values)
data[z_sin] = tmp_sin
data[z_sin].describe()
# Out:
# count    41176.000000
# mean        -0.027285
# std          0.096499
# min         -0.999990
# 25%         -0.026461
# 50%         -0.026461
# 75%         -0.026461
# max          0.990607
# Name: pdays_sin, dtype: float64

# %%
sns.set()
np.random.seed(0)
fig = plt.figure(figsize=(15, 10))
tmp_y = data[z_sin][data['y'] == 'yes']
tmp_n = data[z_sin][data['y'] == 'no']
sns.kdeplot(tmp_y, color='g', label ='yes',shade=True)
sns.kdeplot(tmp_n, color='r', label ='no',shade=True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(9, 7))
sns.violinplot(ax=ax, y=data[z_sin], x=data["y"])

# %% [markdown]
# __The Sine curve of pdays is not an important feature__

# %% [markdown]
# #### previous

# %%
z = 'previous'

# %%
data[z].describe()
# Out:
# count    41176.000000
# mean         0.173013
# std          0.494964
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          7.000000
# Name: previous, dtype: float64

# %%
sns.set()
np.random.seed(0)
fig = plt.figure(figsize=(15, 10))
tmp_y = data[z][data['y'] == 'yes']
tmp_n = data[z][data['y'] == 'no']
sns.kdeplot(tmp_y, color='g', label ='yes',shade=True)
sns.kdeplot(tmp_n, color='r', label ='no',shade=True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(9, 7))
sns.violinplot(ax=ax, y=data[z], x=data["y"])

# %% [markdown]
# __From the above plots we can say that people who are not contacted previously have higher probablity of responding positively to the marketing Campaign__

# %% [markdown]
# ##### sin(previous)

# %%
z_sin = 'previous_sin'

# %%
#get sine of feature and add it to the dataframe
tmp_sin = return_sin(data[z].values)
data[z_sin] = tmp_sin
data[z_sin].describe()
# Out:
# count    41176.000000
# mean         0.108876
# std          0.288480
# min         -0.958924
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          0.909297
# Name: previous_sin, dtype: float64

# %%
sns.set()
np.random.seed(0)
fig = plt.figure(figsize=(15, 10))
tmp_y = data[z_sin][data['y'] == 'yes']
tmp_n = data[z_sin][data['y'] == 'no']
sns.kdeplot(tmp_y, color='g', label ='yes',shade=True)
sns.kdeplot(tmp_n, color='r', label ='no',shade=True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(9, 7))
sns.violinplot(ax=ax, y=data[z_sin], x=data["y"])

# %% [markdown]
# __The Sine of previous is not an important curve as the curve is similar for both positive and negative cases__

# %% [markdown]
# #### emp.var.rate

# %%
z = 'emp.var.rate'

# %%
data[z].describe()
# Out:
# count    41176.000000
# mean         0.081922
# std          1.570883
# min         -3.400000
# 25%         -1.800000
# 50%          1.100000
# 75%          1.400000
# max          1.400000
# Name: emp.var.rate, dtype: float64

# %%
sns.set()
np.random.seed(0)
fig = plt.figure(figsize=(15, 10))
tmp_y = data[z][data['y'] == 'yes']
tmp_n = data[z][data['y'] == 'no']
sns.kdeplot(tmp_y, color='g', label ='yes',shade=True)
sns.kdeplot(tmp_n, color='r', label ='no',shade=True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(9, 7))
sns.violinplot(ax=ax, y=data[z], x=data["y"])

# %% [markdown]
# __The Curve is very effective in seperating the positive and the negative points__

# %% [markdown]
# ##### sin(emp.var.rate)

# %%
z_sin = 'emp.var.rate_sin'

# %%
#get sine of feature and add it to the dataframe
tmp_sin = return_sin(data[z].values)
data[z_sin] = tmp_sin
data[z_sin].describe()
# Out:
# count    41176.000000
# mean         0.294274
# std          0.832499
# min         -0.991665
# 25%         -0.891207
# 50%          0.891207
# 75%          0.985450
# max          0.985450
# Name: emp.var.rate_sin, dtype: float64

# %%
sns.set()
np.random.seed(0)
fig = plt.figure(figsize=(15, 10))
tmp_y = data[z_sin][data['y'] == 'yes']
tmp_n = data[z_sin][data['y'] == 'no']
sns.kdeplot(tmp_y, color='g', label ='yes',shade=True)
sns.kdeplot(tmp_n, color='r', label ='no',shade=True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(9, 7))
sns.violinplot(ax=ax, y=data[z_sin], x=data["y"])

# %% [markdown]
# __The Sine curve of emp.var.rate is very important as we can see a clear divide in the positive and the negative curves from the curve__

# %% [markdown]
# #### cons.price.idx

# %%
z = 'cons.price.idx'

# %%
data[z].describe()
# Out:
# count    41176.000000
# mean        93.575720
# std          0.578839
# min         92.201000
# 25%         93.075000
# 50%         93.749000
# 75%         93.994000
# max         94.767000
# Name: cons.price.idx, dtype: float64

# %%
sns.set()
np.random.seed(0)
fig = plt.figure(figsize=(15, 10))
tmp_y = data[z][data['y'] == 'yes']
tmp_n = data[z][data['y'] == 'no']
sns.kdeplot(tmp_y, color='g', label ='yes',shade=True)
sns.kdeplot(tmp_n, color='r', label ='no',shade=True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(9, 7))
sns.violinplot(ax=ax, y=data[z], x=data["y"])

# %% [markdown]
# __From the above two plots we can say that people respond Positively when cons.price.idx is less than 92.7__

# %% [markdown]
# ##### sin(cons.price.idx)

# %%
z_sin = 'cons.price.idx_sin'

# %%
#get sine of feature and add it to the dataframe
tmp_sin = return_sin(data[z].values)
data[z_sin] = tmp_sin
data[z_sin].describe()
# Out:
# count    41176.000000
# mean        -0.519132
# std          0.398274
# min         -0.999608
# 25%         -0.921832
# 50%         -0.478354
# 75%         -0.251064
# max          0.496203
# Name: cons.price.idx_sin, dtype: float64

# %%
sns.set()
np.random.seed(0)
fig = plt.figure(figsize=(15, 10))
tmp_y = data[z_sin][data['y'] == 'yes']
tmp_n = data[z_sin][data['y'] == 'no']
sns.kdeplot(tmp_y, color='g', label ='yes',shade=True)
sns.kdeplot(tmp_n, color='r', label ='no',shade=True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(9, 7))
sns.violinplot(ax=ax, y=data[z_sin], x=data["y"])

# %% [markdown]
# __Although the curve does not divide the data perfectly but we can see some seperation from the curve__

# %% [markdown]
# #### cons.conf.idx

# %%
z = 'cons.conf.idx'

# %%
data[z].describe()
# Out:
# count    41176.000000
# mean       -40.502863
# std          4.627860
# min        -50.800000
# 25%        -42.700000
# 50%        -41.800000
# 75%        -36.400000
# max        -26.900000
# Name: cons.conf.idx, dtype: float64

# %%
sns.set()
np.random.seed(0)
fig = plt.figure(figsize=(15, 10))
tmp_y = data[z][data['y'] == 'yes']
tmp_n = data[z][data['y'] == 'no']
sns.kdeplot(tmp_y, color='g', label ='yes',shade=True)
sns.kdeplot(tmp_n, color='r', label ='no',shade=True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(9, 7))
sns.violinplot(ax=ax, y=data[z], x=data["y"])

# %% [markdown]
# __The curve of cons.conf.idx is soperable at some parts where the probablity of points being positive is higher__

# %% [markdown]
# ##### sin(cons.conf.idx)

# %%
z_sin = 'cons.conf.idx_sin'

# %%
#get sine of feature and add it to the dataframe
tmp_sin = return_sin(data[z].values)
data[z_sin] = tmp_sin
data[z_sin].describe()
# Out:
# count    41176.000000
# mean         0.502798
# std          0.692173
# min         -0.999912
# 25%         -0.023888
# 50%          0.916522
# 75%          0.963320
# max          0.999599
# Name: cons.conf.idx_sin, dtype: float64

# %%
sns.set()
np.random.seed(0)
fig = plt.figure(figsize=(15, 10))
tmp_y = data[z_sin][data['y'] == 'yes']
tmp_n = data[z_sin][data['y'] == 'no']
sns.kdeplot(tmp_y, color='g', label ='yes',shade=True)
sns.kdeplot(tmp_n, color='r', label ='no',shade=True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(9, 7))
sns.violinplot(ax=ax, y=data[z_sin], x=data["y"])

# %% [markdown]
# __The Sine curve of cons.conf.idx has some very good seperation areas and hence is a good Feature__

# %% [markdown]
# #### euribor3m

# %%
z = 'euribor3m'

# %%
data[z].describe()
# Out:
# count    41176.000000
# mean         3.621293
# std          1.734437
# min          0.634000
# 25%          1.344000
# 50%          4.857000
# 75%          4.961000
# max          5.045000
# Name: euribor3m, dtype: float64

# %%
sns.set()
np.random.seed(0)
fig = plt.figure(figsize=(15, 10))
tmp_y = data[z][data['y'] == 'yes']
tmp_n = data[z][data['y'] == 'no']
sns.kdeplot(tmp_y, color='g', label ='yes',shade=True)
sns.kdeplot(tmp_n, color='r', label ='no',shade=True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(9, 7))
sns.violinplot(ax=ax, y=data[z], x=data["y"])

# %% [markdown]
# __From the above two plots we can say that the feature aeuribor3m is a very important since it shows clear signs of separation of positive and the negative points__

# %% [markdown]
# ##### sin(euribor3m)

# %%
z_sin = 'euribor3m_sin'

# %%
#get sine of feature and add it to the dataframe
tmp_sin = return_sin(data[z].values)
data[z_sin] = tmp_sin
data[z_sin].describe()
# Out:
# count    41176.000000
# mean        -0.351414
# std          0.870723
# min         -0.999923
# 25%         -0.969989
# 50%         -0.968263
# 75%          0.772647
# max          0.999995
# Name: euribor3m_sin, dtype: float64

# %%
sns.set()
np.random.seed(0)
fig = plt.figure(figsize=(15, 10))
tmp_y = data[z_sin][data['y'] == 'yes']
tmp_n = data[z_sin][data['y'] == 'no']
sns.kdeplot(tmp_y, color='g', label ='yes',shade=True)
sns.kdeplot(tmp_n, color='r', label ='no',shade=True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(9, 7))
sns.violinplot(ax=ax, y=data[z_sin], x=data["y"])

# %% [markdown]
# __The Sine curve of euribor3m seperates the positive and the negative points and hence is very important in our analysis__

# %% [markdown]
# #### nr.employed

# %%
z = 'nr.employed'

# %%
data[z].describe()
# Out:
# count    41176.000000
# mean      5167.034870
# std         72.251364
# min       4963.600000
# 25%       5099.100000
# 50%       5191.000000
# 75%       5228.100000
# max       5228.100000
# Name: nr.employed, dtype: float64

# %%
sns.set()
np.random.seed(0)
fig = plt.figure(figsize=(15, 10))
tmp_y = data[z][data['y'] == 'yes']
tmp_n = data[z][data['y'] == 'no']
sns.kdeplot(tmp_y, color='g', label ='yes',shade=True)
sns.kdeplot(tmp_n, color='r', label ='no',shade=True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(9, 7))
sns.violinplot(ax=ax, y=data[z], x=data["y"])

# %% [markdown]
# __The feature nr.employed is a very Important feature and we can clearly see that when nr.employed < 5075 the points are mostly positive__

# %% [markdown]
# ##### sin(nr.employed)

# %%
z_sin = 'nr.employed_sin'

# %%
#get sine of feature and add it to the dataframe
tmp_sin = return_sin(data[z].values)
data[z_sin] = tmp_sin
data[z_sin].describe()
# Out:
# count    41176.000000
# mean         0.243099
# std          0.487991
# min         -0.864770
# 25%         -0.290858
# 50%          0.470471
# 75%          0.470471
# max          0.886134
# Name: nr.employed_sin, dtype: float64

# %%
sns.set()
np.random.seed(0)
fig = plt.figure(figsize=(15, 10))
tmp_y = data[z_sin][data['y'] == 'yes']
tmp_n = data[z_sin][data['y'] == 'no']
sns.kdeplot(tmp_y, color='g', label ='yes',shade=True)
sns.kdeplot(tmp_n, color='r', label ='no',shade=True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(9, 7))
sns.violinplot(ax=ax, y=data[z_sin], x=data["y"])

# %% [markdown]
# __The Sine curve of nr.employed has a lot of overlaping regions between the positive and the negative points but none the less there are some regions with more positive points__

# %% [markdown]
# ### Important Numerical Features after performing EDA on Numerical Features:

# %% [markdown]
# - age
# - sin(age)
# - duration
# - campaign
# - sin(campaign)
# - previous
# - emp.var.rate
# - sin(emp.var.rate)
# - cons.price.idx
# - sin(cons.price.idx)
# - cons.conf.idx
# - sin(cons.conf.idx)
# - euribor3m
# - sin(euribor3m)
# - nr.employed
# - sin(nr.employed)

# %%
data.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y', 'age_sin',
#        'duration_sin', 'campaign_sin', 'pdays_sin', 'previous_sin',
#        'emp.var.rate_sin', 'cons.price.idx_sin', 'cons.conf.idx_sin',
#        'euribor3m_sin', 'nr.employed_sin'],
#       dtype='object')

# %% [markdown]
# ### Exploratory Data Analysis on Categorical Features

# %% [markdown]
# __Categorical Features__
#
# - job
# - marital
# - education
# - default
# - housing
# - loan
# - contact
# - month
# - day_of_week
# - poutcome

# %% [markdown]
# __In the Categorical data we have unknoun data lets change the data to unknown_attribute_name__

# %%
#some col in the dataset have values as unknown we will change it to unknown_col_name

#Replace the unknown job level
data['job'].replace('unknown', 'unknown_job', inplace=True)

#Replace the unknown marital status
data['marital'].replace('unknown', 'unknown_marital', inplace=True)

#Replace the unknown education level
data['education'].replace('unknown', 'unknown_education', inplace=True)

#Replace the unknown default level
data['default'].replace('unknown', 'unknown_default', inplace=True)

#Replace the unknown housing level
data['housing'].replace('unknown', 'unknown_housing', inplace=True)

#Replace the unknown loan level
data['loan'].replace('unknown', 'unknown_loan', inplace=True)

#Replace the unknown and contact level
data['contact'].replace('unknown', 'unknown_contact', inplace=True)

#Replace the unknown and month level
data['month'].replace('unknown', 'unknown_month', inplace=True)

#Replace the unknown and day_of_week level
data['day_of_week'].replace('unknown', 'unknown_day_of_week', inplace=True)

#Replace the unknown and poutcome level
data['poutcome'].replace('unknown', 'unknown_poutcome', inplace=True)

# %% [markdown]
# #### job

# %%
z = 'job'
print(data[z].unique())
print(data[z].value_counts())
# Out:
# ['housemaid' 'services' 'admin.' 'blue-collar' 'technician' 'retired'
#  'management' 'unemployed' 'self-employed' 'unknown_job' 'entrepreneur'
#  'student']
# admin.           10419
# blue-collar       9253
# technician        6739
# services          3967
# management        2924
# retired           1718
# entrepreneur      1456
# self-employed     1421
# housemaid         1060
# unemployed        1014
# student            875
# unknown_job        330
# Name: job, dtype: int64

# %%
#removing 'hiphen' and 'dot' from the category names
data['job'].replace('blue-collar', 'blue_collar', inplace=True)
data['job'].replace('self-employed', 'self_employed', inplace=True)
#checking results
print(data[z].unique())
print(data[z].value_counts())
# Out:
# ['housemaid' 'services' 'admin.' 'blue_collar' 'technician' 'retired'
#  'management' 'unemployed' 'self_employed' 'unknown_job' 'entrepreneur'
#  'student']
# admin.           10419
# blue_collar       9253
# technician        6739
# services          3967
# management        2924
# retired           1718
# entrepreneur      1456
# self_employed     1421
# housemaid         1060
# unemployed        1014
# student            875
# unknown_job        330
# Name: job, dtype: int64

# %%
fig, ax = plt.subplots(figsize =(20, 10)) 
sns.countplot(x=z, hue='y', data = data)

# %% [markdown]
# __students are most likely to respondely positively to the marketing campaign__

# %% [markdown]
# #### marital

# %%
z = 'marital'
print(data[z].unique())
print(data[z].value_counts())
fig, ax = plt.subplots(figsize =(20, 10)) 
sns.countplot(x=z, hue='y', data = data)
# Out:
# ['married' 'single' 'divorced' 'unknown_marital']
# married            24921
# single             11564
# divorced            4611
# unknown_marital       80
# Name: marital, dtype: int64

# %% [markdown]
# __The distribution of the marital status is proportional__

# %% [markdown]
# #### education

# %%
z = 'education'
print(data[z].unique())
print(data[z].value_counts())
# Out:
# ['basic.4y' 'high.school' 'basic.6y' 'basic.9y' 'professional.course'
#  'unknown_education' 'university.degree' 'illiterate']
# university.degree      12164
# high.school             9512
# basic.9y                6045
# professional.course     5240
# basic.4y                4176
# basic.6y                2291
# unknown_education       1730
# illiterate                18
# Name: education, dtype: int64

# %%
#removing 'hiphen' and 'dot' from the category names
data['education'].replace('university.degree', 'university_degree', inplace=True)
data['education'].replace('high.school', 'high_school', inplace=True)
data['education'].replace('basic.9y', 'basic_9y', inplace=True)
data['education'].replace('professional.course', 'professional_course', inplace=True)
data['education'].replace('basic.4y', 'basic_4y', inplace=True)
data['education'].replace('basic.6y', 'basic_6y', inplace=True)
#checking results
print(data[z].unique())
print(data[z].value_counts())
# Out:
# ['basic_4y' 'high_school' 'basic_6y' 'basic_9y' 'professional_course'
#  'unknown_education' 'university_degree' 'illiterate']
# university_degree      12164
# high_school             9512
# basic_9y                6045
# professional_course     5240
# basic_4y                4176
# basic_6y                2291
# unknown_education       1730
# illiterate                18
# Name: education, dtype: int64

# %%
fig, ax = plt.subplots(figsize =(20, 10)) 
sns.countplot(x=z, hue='y', data = data)

# %% [markdown]
# __The distribution of Education attribute proportional__

# %% [markdown]
# #### default

# %%
z = 'default'
print(data[z].unique())
print(data[z].value_counts())
# Out:
# ['no' 'unknown_default' 'yes']
# no                 32577
# unknown_default     8596
# yes                    3
# Name: default, dtype: int64

# %%
#renaming 'yes' and 'no' in the category names
data['default'].replace('yes', 'yes_default', inplace=True)
data['default'].replace('no', 'no_default', inplace=True)
#checking results
print(data[z].unique())
print(data[z].value_counts())
# Out:
# ['no_default' 'unknown_default' 'yes_default']
# no_default         32577
# unknown_default     8596
# yes_default            3
# Name: default, dtype: int64

# %%
fig, ax = plt.subplots(figsize =(20, 10)) 
sns.countplot(x=z, hue='y', data = data)

# %% [markdown]
# __The Distribution of defaulters is very proportional__

# %% [markdown]
# #### housing

# %%
z = 'housing'
print(data[z].unique())
print(data[z].value_counts())
# Out:
# ['no' 'yes' 'unknown_housing']
# yes                21571
# no                 18615
# unknown_housing      990
# Name: housing, dtype: int64

# %%
#renaming 'yes' and 'no' in the category names
data['housing'].replace('yes', 'yes_housing', inplace=True)
data['housing'].replace('no', 'no_housing', inplace=True)
#checking results
print(data[z].unique())
print(data[z].value_counts())
# Out:
# ['no_housing' 'yes_housing' 'unknown_housing']
# yes_housing        21571
# no_housing         18615
# unknown_housing      990
# Name: housing, dtype: int64

# %%
fig, ax = plt.subplots(figsize =(20, 10)) 
sns.countplot(x=z, hue='y', data = data)

# %% [markdown]
# __People with no housing loan are more probable to respond positively to the ad campaign__

# %% [markdown]
# #### loan

# %%
z = 'loan'
print(data[z].unique())
print(data[z].value_counts())
# Out:
# ['no' 'yes' 'unknown_loan']
# no              33938
# yes              6248
# unknown_loan      990
# Name: loan, dtype: int64

# %%
#renaming 'yes' and 'no' in the category names
data['loan'].replace('yes', 'yes_loan', inplace=True)
data['loan'].replace('no', 'no_loan', inplace=True)
#checking results
print(data[z].unique())
print(data[z].value_counts())
# Out:
# ['no_loan' 'yes_loan' 'unknown_loan']
# no_loan         33938
# yes_loan         6248
# unknown_loan      990
# Name: loan, dtype: int64

# %%
fig, ax = plt.subplots(figsize =(20, 10)) 
sns.countplot(x=z, hue='y', data = data)

# %% [markdown]
# __People with no loans are more probable to respond positively to the ad campaign__

# %% [markdown]
# #### contact

# %%
z = 'contact'
print(data[z].unique())
print(data[z].value_counts())
fig, ax = plt.subplots(figsize =(20, 10)) 
sns.countplot(x=z, hue='y', data = data)
# Out:
# ['telephone' 'cellular']
# cellular     26135
# telephone    15041
# Name: contact, dtype: int64

# %% [markdown]
# __People who have been contacted on celular network are most likely to respond positively to the ad campaign__

# %% [markdown]
# #### month

# %%
z = 'month'
print(data[z].unique())
print(data[z].value_counts())
fig, ax = plt.subplots(figsize =(20, 10)) 
sns.countplot(x=z, hue='y', data = data)
# Out:
# ['may' 'jun' 'jul' 'aug' 'oct' 'nov' 'dec' 'mar' 'apr' 'sep']
# may    13767
# jul     7169
# aug     6176
# jun     5318
# nov     4100
# apr     2631
# oct      717
# sep      570
# mar      546
# dec      182
# Name: month, dtype: int64

# %% [markdown]
# __People who are contacted in the months of Oct, Dec, Mar, sep are more likely to respond positively to the ad campaign__

# %% [markdown]
# #### day_of_week

# %%
z = 'day_of_week'
print(data[z].unique())
print(data[z].value_counts())
fig, ax = plt.subplots(figsize =(20, 10)) 
sns.countplot(x=z, hue='y', data = data)
# Out:
# ['mon' 'tue' 'wed' 'thu' 'fri']
# thu    8618
# mon    8512
# wed    8134
# tue    8086
# fri    7826
# Name: day_of_week, dtype: int64

# %% [markdown]
# __People contacted on Tue, Wed, are more likely to respond positively to the ad campaign__

# %% [markdown]
# #### poutcome

# %%
z = 'poutcome'
print(data[z].unique())
print(data[z].value_counts())
# Out:
# ['nonexistent' 'failure' 'success']
# nonexistent    35551
# failure         4252
# success         1373
# Name: poutcome, dtype: int64

# %%
#renaming 'nonexistent', 'failure', 'success' in the category names
data['poutcome'].replace('nonexistent', 'nonexistent_poutcome', inplace=True)
data['poutcome'].replace('failure', 'failure_poutcome', inplace=True)
data['poutcome'].replace('success', 'success_poutcome', inplace=True)
#checking results
print(data[z].unique())
print(data[z].value_counts())
# Out:
# ['nonexistent_poutcome' 'failure_poutcome' 'success_poutcome']
# nonexistent_poutcome    35551
# failure_poutcome         4252
# success_poutcome         1373
# Name: poutcome, dtype: int64

# %%
fig, ax = plt.subplots(figsize =(20, 10)) 
sns.countplot(x=z, hue='y', data = data)

# %% [markdown]
# __People who have earlier positively responded to the ad campaign have high probablity of success__

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Geting Thresholds from Numerical Features

# %% [markdown]
# __lets train simple Decision Stump on our Numerical Data(One Feature at a time) and get thresholds from them__

# %% [markdown]
# __We can convert the Neumerical Features to Categorical Features if Weighted F1-score of the decission stump is greater than 0.85__

# %% [markdown]
# __Numerical Features__
# - age
# - duration
# - campaign
# - pdays
# - previous
# - emp.var.rate
# - cons.price.idx
# - cons.conf.idx
# - euribor3m
# - nr.employed

# %%
#First we will have to convert y label to 0/1 for yes/no and we will use label encoder for this purpose
y_label = df['y'] #get output variable
le = LabelEncoder()
output = le.fit_transform(y_label) #transform the output variable to 0/1 form
df['output'] = output

# %%
#get the data of output col in the data_y col
data_y = data['output'].values.reshape(-1,1)

# %% [markdown]
# #### age

# %%
#lets get the data of the col
z = 'age'
data_z = data[z].values.reshape(-1, 1)

#lets fit a simple decission stump on the col data
clf = DecisionTreeClassifier(class_weight='balanced',max_depth=1, random_state=40)
clf.fit(data_z, data_y)
y_hat = clf.predict(data_z)
#Now since our data is imbalanced we will use F1-score as our perfornmance metric
F1 = f1_score(data_y, y_hat, average='weighted')
print('The Weighted F1 Score for {} feature is {}'.format(z, F1))

#lets plot the Tree
fig, ax = plt.subplots(figsize=(10, 10), facecolor='k')
plot_tree(clf, feature_names=z, class_names=['no','yes'], filled=True, ax = ax)
# Out:
# The Weighted F1 Score for age feature is 0.848906988824511
# [Text(279.0, 407.70000000000005, 'a <= 59.5\nentropy = 0.5\nsamples = 41176\nvalue = [20588.0, 20588.0]\nclass = yes'),
#  Text(139.5, 135.89999999999998, 'entropy = 0.499\nsamples = 39984\nvalue = [20182.292, 18493.252]\nclass = no'),
#  Text(418.5, 135.89999999999998, 'entropy = 0.272\nsamples = 1192\nvalue = [405.708, 2094.748]\nclass = yes')]

# %% [markdown]
#  __From the Tree we see that when if age > 59.5, We can reasonably seperate the positive and Negative points with f1-score of 0.847__

# %% [markdown]
# #### duration

# %%
#lets get the data of the col
z = 'duration'
data_z = data[z].values.reshape(-1, 1)

#lets fit a simple decission stump on the col data
clf = DecisionTreeClassifier(class_weight='balanced',max_depth=1, random_state=40)
clf.fit(data_z, data_y)
y_hat = clf.predict(data_z)
#Now since our data is imbalanced we wii use F1-score as our perfornmance metric
F1 = f1_score(data_y, y_hat, average='weighted')
print('The Weighted F1 Score for {} feature is {}'.format(z, F1))

#lets plot the Tree
fig, ax = plt.subplots(figsize=(10, 10), facecolor='k')
plot_tree(clf, feature_names=z, class_names=['no','yes'], filled=True, ax = ax)
# Out:
# The Weighted F1 Score for duration feature is 0.7624943406534964
# [Text(279.0, 407.70000000000005, 'd <= 249.5\nentropy = 0.5\nsamples = 41176\nvalue = [20588.0, 20588.0]\nclass = yes'),
#  Text(139.5, 135.89999999999998, 'entropy = 0.379\nsamples = 26858\nvalue = [14505.195, 4952.836]\nclass = no'),
#  Text(418.5, 135.89999999999998, 'entropy = 0.403\nsamples = 14318\nvalue = [6082.805, 15635.164]\nclass = yes')]

# %% [markdown]
# __From the Tree we see that when if duration > 249.5, We can reasonably seperate the positive and Negative points with f1-score of 0.76__

# %% [markdown]
# #### campaign

# %%
#lets get the data of the col
z = 'campaign'
data_z = data[z].values.reshape(-1, 1)

#lets fit a simple decission stump on the col data
clf = DecisionTreeClassifier(class_weight='balanced',max_depth=1, random_state=40)
clf.fit(data_z, data_y)
y_hat = clf.predict(data_z)
#Now since our data is imbalanced we wii use F1-score as our perfornmance metric
F1 = f1_score(data_y, y_hat, average='weighted')
print('The Weighted F1 Score for {} feature is {}'.format(z, F1))

#lets plot the Tree
fig, ax = plt.subplots(figsize=(10, 10), facecolor='k')
plot_tree(clf, feature_names=z, class_names=['no','yes'], filled=True, ax = ax)
# Out:
# The Weighted F1 Score for campaign feature is 0.2238568854145621
# [Text(279.0, 407.70000000000005, 'c <= 4.5\nentropy = 0.5\nsamples = 41176\nvalue = [20588.0, 20588.0]\nclass = yes'),
#  Text(139.5, 135.89999999999998, 'entropy = 0.499\nsamples = 36192\nvalue = [17952.024, 19229.964]\nclass = yes'),
#  Text(418.5, 135.89999999999998, 'entropy = 0.449\nsamples = 4984\nvalue = [2635.976, 1358.036]\nclass = no')]

# %% [markdown]
# __This feature will not seperate the positive and negative points with decision Stump__

# %% [markdown]
# #### pdays

# %%
#lets get the data of the col
z = 'pdays'
data_z = data[z].values.reshape(-1, 1)

#lets fit a simple decission stump on the col data
clf = DecisionTreeClassifier(class_weight='balanced',max_depth=1, random_state=40)
clf.fit(data_z, data_y)
y_hat = clf.predict(data_z)
#Now since our data is imbalanced we wii use F1-score as our perfornmance metric
F1 = f1_score(data_y, y_hat, average='weighted')
print('The Weighted F1 Score for {} feature is {}'.format(z, F1))

#lets plot the Tree
fig, ax = plt.subplots(figsize=(10, 10), facecolor='k')
plot_tree(clf, feature_names=z, class_names=['no','yes'], filled=True, ax = ax)
# Out:
# The Weighted F1 Score for pdays feature is 0.8736009328329177
# [Text(279.0, 407.70000000000005, 'p <= 513.0\nentropy = 0.5\nsamples = 41176\nvalue = [20588.0, 20588.0]\nclass = yes'),
#  Text(139.5, 135.89999999999998, 'entropy = 0.125\nsamples = 1515\nvalue = [308.789, 4291.571]\nclass = yes'),
#  Text(418.5, 135.89999999999998, 'entropy = 0.494\nsamples = 39661\nvalue = [20279.211, 16296.429]\nclass = no')]

# %% [markdown]
# __From the Tree we see that when if pdays < 513, We can reasonably seperate the positive and Negative points with f1-score of 0.87__

# %% [markdown]
# __Lets create a categorical feature as pdays_cat with entries as pdays_yes and pdays_no based on the threshold__

# %%
#data['pdays_cat'] = convert_pdays_cat(data['pdays'])
convert_pdays_cat(data)

# %% [markdown]
# #### previous

# %%
#lets get the data of the col
z = 'previous'
data_z = data[z].values.reshape(-1, 1)

#lets fit a simple decission stump on the col data
clf = DecisionTreeClassifier(class_weight='balanced',max_depth=1, random_state=40)
clf.fit(data_z, data_y)
y_hat = clf.predict(data_z)
#Now since our data is imbalanced we wii use F1-score as our perfornmance metric
F1 = f1_score(data_y, y_hat, average='weighted')
print('The Weighted F1 Score for {} feature is {}'.format(z, F1))

#lets plot the Tree
fig, ax = plt.subplots(figsize=(10, 10), facecolor='k')
plot_tree(clf, feature_names=z, class_names=['no','yes'], filled=True, ax = ax)
# Out:
# The Weighted F1 Score for previous feature is 0.8308069995108132
# [Text(279.0, 407.70000000000005, 'p <= 0.5\nentropy = 0.5\nsamples = 41176\nvalue = [20588.0, 20588.0]\nclass = yes'),
#  Text(139.5, 135.89999999999998, 'entropy = 0.491\nsamples = 35551\nvalue = [18263.067, 13935.4]\nclass = no'),
#  Text(418.5, 135.89999999999998, 'entropy = 0.384\nsamples = 5625\nvalue = [2324.933, 6652.6]\nclass = yes')]

# %% [markdown]
# __From the Tree we see that when if previous > 0.5, We can reasonably seperate the positive and Negative points with f1-score of 0.83__

# %% [markdown]
# #### emp.var.rate

# %%
#lets get the data of the col
z = 'emp.var.rate'
data_z = data[z].values.reshape(-1, 1)

#lets fit a simple decission stump on the col data
clf = DecisionTreeClassifier(class_weight='balanced',max_depth=1, random_state=40)
clf.fit(data_z, data_y)
y_hat = clf.predict(data_z)
#Now since our data is imbalanced we wii use F1-score as our perfornmance metric
F1 = f1_score(data_y, y_hat, average='weighted')
print('The Weighted F1 Score for {} feature is {}'.format(z, F1))

#lets plot the Tree
fig, ax = plt.subplots(figsize=(10, 10), facecolor='k')
plot_tree(clf, feature_names=z, class_names=['no','yes'], filled=True, ax = ax)
# Out:
# The Weighted F1 Score for emp.var.rate feature is 0.7689882963782584
# [Text(279.0, 407.70000000000005, 'e <= -0.65\nentropy = 0.5\nsamples = 41176\nvalue = [20588.0, 20588.0]\nclass = yes'),
#  Text(139.5, 135.89999999999998, 'entropy = 0.405\nsamples = 13494\nvalue = [5744.152, 14645.484]\nclass = yes'),
#  Text(418.5, 135.89999999999998, 'entropy = 0.408\nsamples = 27682\nvalue = [14843.848, 5942.516]\nclass = no')]

# %% [markdown]
# __From the Tree we see that when if emp.var.rate < -0.65, We can reasonably seperate the positive and Negative points with f1-score of 0.77__

# %% [markdown]
# #### cons.price.idx

# %%
#lets get the data of the col
z = 'cons.price.idx'
data_z = data[z].values.reshape(-1, 1)

#lets fit a simple decission stump on the col data
clf = DecisionTreeClassifier(class_weight='balanced',max_depth=1, random_state=40)
clf.fit(data_z, data_y)
y_hat = clf.predict(data_z)
#Now since our data is imbalanced we wii use F1-score as our perfornmance metric
F1 = f1_score(data_y, y_hat, average='weighted')
print('The Weighted F1 Score for {} feature is {}'.format(z, F1))

#lets plot the Tree
fig, ax = plt.subplots(figsize=(10, 10), facecolor='k')
plot_tree(clf, feature_names=z, class_names=['no','yes'], filled=True, ax = ax)
# Out:
# The Weighted F1 Score for cons.price.idx feature is 0.8584848858303336
# [Text(279.0, 407.70000000000005, 'c <= 92.868\nentropy = 0.5\nsamples = 41176\nvalue = [20588.0, 20588.0]\nclass = yes'),
#  Text(139.5, 135.89999999999998, 'entropy = 0.267\nsamples = 2481\nvalue = [835.646, 4429.149]\nclass = yes'),
#  Text(418.5, 135.89999999999998, 'entropy = 0.495\nsamples = 38695\nvalue = [19752.354, 16158.851]\nclass = no')]

# %% [markdown]
# __From the Tree we see that when if cons.price.idx < 92.868, We can reasonably seperate the positive and Negative points with f1-score of 0.86__

# %% [markdown]
# __As the f1-score in this case is > 0.85 we will create a categorical veriable from cons.price.idx named cons.price.idx_cat with entries as cons_price_idx_yes and cons_price_idx_no__

# %%
#data['cons_price_idx'] = convert_cons_price_idx_cat(data['cons.price.idx'])
convert_cons_price_idx_cat(data)

# %% [markdown]
# #### cons.conf.idx

# %%
#lets get the data of the col
z = 'cons.conf.idx'
data_z = data[z].values.reshape(-1, 1)

#lets fit a simple decission stump on the col data
clf = DecisionTreeClassifier(class_weight='balanced',max_depth=1, random_state=40)
clf.fit(data_z, data_y)
y_hat = clf.predict(data_z)
#Now since our data is imbalanced we wii use F1-score as our perfornmance metric
F1 = f1_score(data_y, y_hat, average='weighted')
print('The Weighted F1 Score for {} feature is {}'.format(z, F1))

#lets plot the Tree
fig, ax = plt.subplots(figsize=(10, 10), facecolor='k')
plot_tree(clf, feature_names=z, class_names=['no','yes'], filled=True, ax = ax)
# Out:
# The Weighted F1 Score for cons.conf.idx feature is 0.8625649128917185
# [Text(279.0, 407.70000000000005, 'c <= -35.45\nentropy = 0.5\nsamples = 41176\nvalue = [20588.0, 20588.0]\nclass = yes'),
#  Text(139.5, 135.89999999999998, 'entropy = 0.493\nsamples = 38549\nvalue = [19737.703, 15626.288]\nclass = no'),
#  Text(418.5, 135.89999999999998, 'entropy = 0.25\nsamples = 2627\nvalue = [850.297, 4961.712]\nclass = yes')]

# %% [markdown]
# __From the Tree we see that when if cons.conf.idx < -35.45, We can reasonably seperate the positive and Negative points with f1-score of 0.87__

# %% [markdown]
# __As the f1-score in this case is > 0.85 we will create a categorical veriable from cons.conf.idx named cons.conf.idx_cat with entries as cons_conf_idx_yes and cons_conf_idx_no__

# %%
#data['cons_conf_idx'] = convert_cons_conf_idx_cat(data['cons.conf.idx'])
convert_cons_conf_idx_cat(data)

# %% [markdown]
# #### euribor3m

# %%
#lets get the data of the col
z = 'euribor3m'
data_z = data[z].values.reshape(-1, 1)

#lets fit a simple decission stump on the col data
clf = DecisionTreeClassifier(class_weight='balanced',max_depth=1, random_state=40)
clf.fit(data_z, data_y)
y_hat = clf.predict(data_z)
#Now since our data is imbalanced we wii use F1-score as our perfornmance metric
F1 = f1_score(data_y, y_hat, average='weighted')
print('The Weighted F1 Score for {} feature is {}'.format(z, F1))

#lets plot the Tree
fig, ax = plt.subplots(figsize=(10, 10), facecolor='k')
plot_tree(clf, feature_names=z, class_names=['no','yes'], filled=True, ax = ax)
# Out:
# The Weighted F1 Score for euribor3m feature is 0.7690097967416025
# [Text(279.0, 407.70000000000005, 'e <= 3.168\nentropy = 0.5\nsamples = 41176\nvalue = [20588.0, 20588.0]\nclass = yes'),
#  Text(139.5, 135.89999999999998, 'entropy = 0.405\nsamples = 13495\nvalue = [5744.152, 14649.922]\nclass = yes'),
#  Text(418.5, 135.89999999999998, 'entropy = 0.408\nsamples = 27681\nvalue = [14843.848, 5938.078]\nclass = no')]

# %% [markdown]
# __From the Tree we see that when if euribor3m < 2.57, We can reasonably seperate the positive and Negative points with f1-score of 0.77__

# %% [markdown]
# #### nr.employed

# %%
#lets get the data of the col
z = 'nr.employed'
data_z = data[z].values.reshape(-1, 1)

#lets fit a simple decission stump on the col data
clf = DecisionTreeClassifier(class_weight='balanced',max_depth=1, random_state=40)
clf.fit(data_z, data_y)
y_hat = clf.predict(data_z)
#Now since our data is imbalanced we wii use F1-score as our perfornmance metric
F1 = f1_score(data_y, y_hat, average='weighted')
print('The Weighted F1 Score for {} feature is {}'.format(z, F1))

#lets plot the Tree
fig, ax = plt.subplots(figsize=(10, 10), facecolor='k')
plot_tree(clf, feature_names=z, class_names=['no','yes'], filled=True, ax = ax)
# Out:
# The Weighted F1 Score for nr.employed feature is 0.8759157653076707
# [Text(279.0, 407.70000000000005, 'n <= 5087.65\nentropy = 0.5\nsamples = 41176\nvalue = [20588.0, 20588.0]\nclass = yes'),
#  Text(139.5, 135.89999999999998, 'entropy = 0.236\nsamples = 4962\nvalue = [1551.834, 9799.16]\nclass = yes'),
#  Text(418.5, 135.89999999999998, 'entropy = 0.462\nsamples = 36214\nvalue = [19036.166, 10788.84]\nclass = no')]

# %% [markdown]
# __From the Tree we see that when if nr.employed < 5087.65, We can reasonably seperate the positive and Negative points with f1-score of 0.87__

# %% [markdown]
# __As the f1-score in this case is > 0.85 we will create a categorical veriable from nr.employed named nr.employed_cat with entries as nr_employed_yes and nr_employed_no__

# %%
#data['nr.employed_cat'] = convert_nr_employed_cat(data['nr.employed'])
convert_nr_employed_cat(data)

# %% [markdown]
# __The neumerical features from which categorical features were created are : pdays, cons.price.idx, cons.conf.idx, nr.employed__

# %% [markdown]
# ## Data Preparation for ML Models

# %% [markdown]
# - In the Dataset we had 20 Input Features and one Feature for y label ie. 21 features
# - Here we added 10 more numerical features for sin function
# - Also we converted 4 numerical features to categorical features using Decision Stump
# - A feature named output was also added
# - So the total Features are 36

# %% [markdown]
# ### Lets do a Train-Test Split

# %%
df.head()
# Out:
#    age        job  marital    education          default      housing  \
# 0   56  housemaid  married     basic_4y       no_default   no_housing
# 1   57   services  married  high_school  unknown_default   no_housing
# 2   37   services  married  high_school       no_default  yes_housing
# 3   40     admin.  married     basic_6y       no_default   no_housing
# 4   56   services  married  high_school       no_default   no_housing
#
#        loan    contact month day_of_week  ...  emp.var.rate_sin  \
# 0   no_loan  telephone   may         mon  ...          0.891207
# 1   no_loan  telephone   may         mon  ...          0.891207
# 2   no_loan  telephone   may         mon  ...          0.891207
# 3   no_loan  telephone   may         mon  ...          0.891207
# 4  yes_loan  telephone   may         mon  ...          0.891207
#
#    cons.price.idx_sin  cons.conf.idx_sin  euribor3m_sin nr.employed_sin  \
# 0           -0.251064            0.96332      -0.989562        0.886134
# ...

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y', 'age_sin',
#        'duration_sin', 'campaign_sin', 'pdays_sin', 'previous_sin',
#        'emp.var.rate_sin', 'cons.price.idx_sin', 'cons.conf.idx_sin',
#        'euribor3m_sin', 'nr.employed_sin', 'output', 'pdays_cat',
#        'cons.price.idx_cat', 'cons.conf.idx_cat', 'nr.employed_cat'],
#       dtype='object')

# %%
#here we will split our data randomly as there is no temporal nature of the data
Y_True = df['output'].values.reshape(-1,1)

#remove the 'y' and 'output' columns
df.drop(['y'], axis=1, inplace=True)
df.drop(['output'], axis=1, inplace=True)
print(df.shape)
print(df.columns)
# Out:
# (41176, 34)
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'age_sin', 'duration_sin',
#        'campaign_sin', 'pdays_sin', 'previous_sin', 'emp.var.rate_sin',
#        'cons.price.idx_sin', 'cons.conf.idx_sin', 'euribor3m_sin',
#        'nr.employed_sin', 'pdays_cat', 'cons.price.idx_cat',
#        'cons.conf.idx_cat', 'nr.employed_cat'],
#       dtype='object')

# %%
#splitting the data to train and test
df_Train_temp, df_Test, Y_Train_temp, Y_Test = train_test_split(df, Y_True, stratify=Y_True, test_size=0.3, random_state = 4) 
df_Train, df_CV, Y_Train, Y_CV = train_test_split(df_Train_temp, Y_Train_temp, stratify=Y_Train_temp, test_size=0.3, random_state = 4)

# %%
#lets see the shape of the train cv and test data
print('df_train shape: {} Y_train shape: {}'.format(df_Train.shape, Y_Train.shape))
print('df_CV shape: {} Y_CV shape: {}'.format(df_CV.shape, Y_CV.shape))
print('df_test shape: {} Y_test shape: {}'.format(df_Test.shape, Y_Test.shape))
# Out:
# df_train shape: (20176, 34) Y_train shape: (20176, 1)
# df_CV shape: (8647, 34) Y_CV shape: (8647, 1)
# df_test shape: (12353, 34) Y_test shape: (12353, 1)

# %% [markdown]
# ### Standardizing the Features in the Train, CV and Test Datasets

# %% [markdown]
# __We have 34 Features out of which 20 are numerical features while 14 are categorical features, so for the numerical features we will use standard_scalar while for the categorical features we will use countvectorizer__
#
# __Here we will use a function standerdize_data to standardize the data__

# %%
#This function will standardize the data given a dataframe
#if the data is train data we will have to call to the function with tag = 1
#if the data is test/cv we will have to call the function with tag = 0
#The function will return the the np array after standardization process
#The standard_dict_cat is a dictionary of categorical feature names and their corresponding countvectorizer objects
#The standard_dict_num is a dictionary of numerical feature names and their corresponding standardscalar objects
#if the training data is provided the function will add values to the dectionaries standard_dict_cat,standard_dict_num
# Initially both the dectionaries will be initialized as <'feature_name':0>
# The value will be filled in the train process
# The same dictionaries will be used with the test/cv to transform data


def standardize_data(dataframe, tag, standard_dict_cat, standard_dict_num):
    #if the training data is passed with 0 initialized dectionaries
    if tag == 1:
        #Initialize the feature list
        features = []
        #Initialize the array for hstacking in the end
        array = []
        #convert categorical features to one hot encoding using countvectorizer
        for cat in standard_dict_cat.keys():
            #initialize the vectorizer
            vectorizer = CountVectorizer()
            #fit and transform train data
            X = vectorizer.fit_transform(dataframe[cat])
            #get feature names
            Z = vectorizer.get_feature_names()
            #add vectorizer to the dectionary
            standard_dict_cat[cat] = vectorizer
            #add features to the feature array
            features.extend(Z)
            #add data to the np array
            array.append(X)
        #scale numerical features using standardscalar
        for num in standard_dict_num.keys():
            #initialize the standardscalar
            scaler = StandardScaler()
            #fit and transform train data
            X = scaler.fit_transform(dataframe[num].values.reshape(-1, 1))
            #add scalar to the dectionary
            standard_dict_num[num] = scaler
            #add features to the feature array
            features.append(num)
            #add data to the np array
            array.append(X)

        #preparing np array for returing
        data_stand = sparse.hstack(
            (array[0], array[1], array[2], array[3], array[4], array[5],
             array[6], array[7], array[8], array[9], array[10], array[11],
             array[12], array[13], array[14], array[15], array[16], array[17],
             array[18], array[19], array[20], array[21], array[22], array[23],
             array[24], array[25], array[26], array[27], array[28], array[29],
             array[30], array[31], array[32], array[33]))
        #return data and the features
        return data_stand, features
    if tag == 0:
        #Initialize the feature list
        features = []
        #Initialize the array for hstacking in the end
        array = []
        #convert categorical features to one hot encoding using countvectorizer
        for cat in standard_dict_cat.keys():
            #transform train data
            X = standard_dict_cat[cat].transform(dataframe[cat])
            #get feature names
            Z = standard_dict_cat[cat].get_feature_names()
            #add features to the feature array
            features.extend(Z)
            #add data to the np array
            array.append(X)
        #scale numerical features using standardscalar
        for num in standard_dict_num.keys():
            #transform train data
            X = standard_dict_num[num].transform(dataframe[num].values.reshape(
                -1, 1))
            #add features to the feature array
            features.append(num)
            #add data to the np array
            array.append(X)

        #preparing np array for returing
        data_stand = sparse.hstack(
            (array[0], array[1], array[2], array[3], array[4], array[5],
             array[6], array[7], array[8], array[9], array[10], array[11],
             array[12], array[13], array[14], array[15], array[16], array[17],
             array[18], array[19], array[20], array[21], array[22], array[23],
             array[24], array[25], array[26], array[27], array[28], array[29],
             array[30], array[31], array[32], array[33]))

        #return data and the features
        return data_stand, features
    else:
        return 'Please input a valid tag'

# %%
#get all cols of the data
cols = list(df_Train.columns)
print(cols)
# Out:
# ['age', 'job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays', 'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed', 'age_sin', 'duration_sin', 'campaign_sin', 'pdays_sin', 'previous_sin', 'emp.var.rate_sin', 'cons.price.idx_sin', 'cons.conf.idx_sin', 'euribor3m_sin', 'nr.employed_sin', 'pdays_cat', 'cons.price.idx_cat', 'cons.conf.idx_cat', 'nr.employed_cat']

# %%
#categorical features
cols_cat = [
    'job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
    'month', 'day_of_week', 'poutcome', 'pdays_cat', 'cons.price.idx_cat',
    'cons.conf.idx_cat', 'nr.employed_cat'
]
print('cols_cat')
print(cols_cat,len(cols_cat))

#numerical features
cols_num = [
    'age', 'duration', 'campaign', 'pdays', 'previous', 'emp.var.rate',
    'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed', 'age_sin',
    'duration_sin', 'campaign_sin', 'pdays_sin', 'previous_sin',
    'emp.var.rate_sin', 'cons.price.idx_sin', 'cons.conf.idx_sin',
    'euribor3m_sin', 'nr.employed_sin'
]
print('cols_num')
print(cols_num,len(cols_num))

#initializing the standard_dict_cat dectionary
standard_dict_cat = dict.fromkeys(cols_cat,0)
print('standard_dict_cat')
print(standard_dict_cat)

#initializing the standard_dict_num dectionary
standard_dict_num = dict.fromkeys(cols_num,0)
print('standard_dict_num')
print(standard_dict_num)
# Out:
# cols_cat
# ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'poutcome', 'pdays_cat', 'cons.price.idx_cat', 'cons.conf.idx_cat', 'nr.employed_cat'] 14
# cols_num
# ['age', 'duration', 'campaign', 'pdays', 'previous', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed', 'age_sin', 'duration_sin', 'campaign_sin', 'pdays_sin', 'previous_sin', 'emp.var.rate_sin', 'cons.price.idx_sin', 'cons.conf.idx_sin', 'euribor3m_sin', 'nr.employed_sin'] 20
# standard_dict_cat
# {'job': 0, 'marital': 0, 'education': 0, 'default': 0, 'housing': 0, 'loan': 0, 'contact': 0, 'month': 0, 'day_of_week': 0, 'poutcome': 0, 'pdays_cat': 0, 'cons.price.idx_cat': 0, 'cons.conf.idx_cat': 0, 'nr.employed_cat': 0}
# standard_dict_num
# ...

# %%
#standerdizing train data
x_train, train_features = standardize_data(df_Train, 1, standard_dict_cat, standard_dict_num)
#standerdizing cv data
x_cv, cv_features = standardize_data(df_CV, 0, standard_dict_cat, standard_dict_num)
#standerdizing test data
x_test, test_features= standardize_data(df_Test, 0, standard_dict_cat, standard_dict_num)

# %%
#check if the feature names are same for train cv and test data
if train_features == cv_features == test_features:
    print(True)
# Out:
# True

# %%
#checking the shape and vales of train features
print(len(train_features))
print(train_features)
# Out:
# 81
# ...

# %% [markdown]
# __We have our train data as x_train our cv data as x_cv and our test data as x_test__

# %% [markdown]
# ## Converting Real World Problem to ML Problem

# %% [markdown]
# __Constrains__
# - The False Positives should be less
# - Precession and Recall should be high
# - Also cost of misclassification is high as that would lead in negative publicity of the bank
# - There is no time constrains but should not take hours

# %% [markdown]
# __KPI__
# - The KPI's we will track for this are:
# - AUC
# - F1 Score
# - log loss
# - Confusion Matrix

# %% [markdown]
# __Models__
# - Logistic Regression
# - Naive Bayes
# - Linear SVM
# - Decision Tree
# - Random Forest
# - XGBoost
# - Simple Neural Network
# - Stacking Classifier
# - Voting Classifier

# %% [markdown]
# ## Machine Learning Models

# %%
print(type(x_train),type(x_cv),type(x_test),type(Y_Train),type(Y_CV),type(Y_Test))
# Out:
# <class 'scipy.sparse.coo.coo_matrix'> <class 'scipy.sparse.coo.coo_matrix'> <class 'scipy.sparse.coo.coo_matrix'> <class 'numpy.ndarray'> <class 'numpy.ndarray'> <class 'numpy.ndarray'>

# %%
X_Train = x_train.toarray()
X_CV = x_cv.toarray()
X_Test = x_test.toarray()

# %%
print(type(X_Train),type(X_CV),type(X_Test),type(Y_Train),type(Y_CV),type(Y_Test))
# Out:
# <class 'numpy.ndarray'> <class 'numpy.ndarray'> <class 'numpy.ndarray'> <class 'numpy.ndarray'> <class 'numpy.ndarray'> <class 'numpy.ndarray'>

# %% [markdown]
# ### Logistic Regression

# %%
AUC_Train = []
AUC_CV = []
AUC_Test = []

loss_Train = []
loss_CV = []
loss_Test = []

F1_Train = []
F1_CV = []
F1_Test = []

#code for hyperparameter tuning the logistic regression
c = 0.00001
for i in range(1,9):
    clf = LogisticRegression(C = c, class_weight = 'balanced')
    clf.fit(X_Train, Y_Train)
    Y_Predicted = clf.predict_proba(X_CV)
    y_Predicted = clf.predict(X_CV)
    Y_Predicted = Y_Predicted[:,1]
    acv = roc_auc_score(Y_CV, Y_Predicted)
    AUC_CV.append(acv)
    lcv = log_loss(Y_CV, Y_Predicted)
    loss_CV.append(lcv)
    F1cv = f1_score(Y_CV, y_Predicted, average='weighted')
    F1_CV.append(F1cv)
    Y_Predicted = clf.predict_proba(X_Train)
    y_Predicted = clf.predict(X_Train)
    Y_Predicted = Y_Predicted[:,1]
    at = roc_auc_score(Y_Train, Y_Predicted)
    AUC_Train.append(at)
    lt = log_loss(Y_Train, Y_Predicted)
    loss_Train.append(lt)
    F1t = f1_score(Y_Train, y_Predicted, average='weighted')
    F1_Train.append(F1t)
    c = c*10

# %%
#plotting hyperparameter AUC curve 
x_axis = [-5, -4, -3, -2, -1, 0, 1, 2]
plt.plot(x_axis, AUC_CV, label='Validation AUC')
plt.plot(x_axis, AUC_Train, label='Train AUC')
plt.xlabel('Hyperparameter')
plt.ylabel('Area under ROC curve')
plt.title("HyperParameter Tuning Curve (AUC)")
plt.legend()

# %%
#plotting hyperparameter Log-Loss curve 
x_axis = [-5, -4, -3, -2, -1, 0, 1, 2]
plt.plot(x_axis, loss_CV, label='Validation loss')
plt.plot(x_axis, loss_Train, label='Train loss')
plt.xlabel('Hyperparameter')
plt.ylabel('Log-Loss curve')
plt.title("HyperParameter Tuning Curve (Log-Loss)")
plt.legend()

# %%
#plotting hyperparameter F1-Score curve 
x_axis = [-5, -4, -3, -2, -1, 0, 1, 2]
plt.plot(x_axis, F1_CV, label='Validation F1-Score')
plt.plot(x_axis, F1_Train, label='Train F1-Score')
plt.xlabel('Hyperparameter')
plt.ylabel('F1-Score curve')
plt.title("HyperParameter Tuning Curve (F1-Score)")
plt.legend()

# %% [markdown]
# __The best hyperparameter for Logistic Regression is c=0.001__

# %%
#Training model with c = 0.001
clf = LogisticRegression(C = 0.001, class_weight = 'balanced')
clf.fit(X_Train, Y_Train)
Y_Predicted_Train = clf.predict_proba(X_Train)
Y_Predicted_Train = Y_Predicted_Train[:,-1]
Y_Predicted_Test = clf.predict_proba(X_Test)
Y_Predicted_Test = Y_Predicted_Test[:,-1]

# %%
# Calculating the ROC values  
#https://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_curve.html
fpr_Train, tpr_Train, thresholds_Train = roc_curve(Y_Train, Y_Predicted_Train)
fpr_Test, tpr_Test, thresholds_Test = roc_curve(Y_Test, Y_Predicted_Test)

# %%
#Plotting ROC Curve
plt.plot(fpr_Test, tpr_Test, label='Test ROC')
plt.plot(fpr_Train, tpr_Train, label='Train ROC')
plt.plot([0,1], [0,1], label='Random ROC')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.title("AUC-ROC Curve")
plt.legend()

# %%
#printing the scores
print('The auc is: ',roc_auc_score(Y_Test, Y_Predicted_Test))
print('The log loss is: ',log_loss(Y_Test, Y_Predicted_Test))
y_Predicted_Test = clf.predict(X_Test)
print('The F1-Score is: ',f1_score(Y_Test, y_Predicted_Test, average='weighted'))
# Out:
# The auc is:  0.9295261963261595
# The log loss is:  0.38209830415634705
# The F1-Score is:  0.8733040737184175

# %%
#initializing some variables for future use
lr_auc = roc_auc_score(Y_Test, Y_Predicted_Test)
lr_loss = log_loss(Y_Test, Y_Predicted_Test)
lr_f1_score = f1_score(Y_Test, y_Predicted_Test, average='weighted')

# %%
#plotting confusion matrix
Y_Predicted_Test =np.array(Y_Predicted_Test>0.5,dtype=int)
print("Total number of data points :", len(Y_Predicted_Test))
plot_confusion_matrix(Y_Test, Y_Predicted_Test)
# Out:
# Total number of data points : 12353

# %% [markdown]
# __Conclusions__
#
# - The model performs reasonably well with f1_score = 0.8788
# - The True Negative values are high
# - The True Positive values are decent
# - The False Negatives are also low
# - The False Positives are high which is bad

# %% [markdown]
# ### Naive Bayes

# %%
AUC_Train = []
AUC_CV = []
AUC_Test = []

loss_Train = []
loss_CV = []
loss_Test = []

F1_Train = []
F1_CV = []
F1_Test = []
    
temp = 0.0001
#hyperparameter tuning for Naive Bayes
for i in range(1,10):
    clf = GaussianNB(var_smoothing = temp, priors=[0.5,0.5])
    clf.fit(X_Train, Y_Train)
    Y_Predicted = clf.predict_proba(X_CV)
    y_Predicted = clf.predict(X_CV)
    Y_Predicted = Y_Predicted[:,1]
    acv = roc_auc_score(Y_CV, Y_Predicted)
    AUC_CV.append(acv)
    lcv = log_loss(Y_CV, Y_Predicted)
    loss_CV.append(lcv)
    F1cv = f1_score(Y_CV, y_Predicted, average='weighted')
    F1_CV.append(F1cv)
    Y_Predicted = clf.predict_proba(X_Train)
    y_Predicted = clf.predict(X_Train)
    Y_Predicted = Y_Predicted[:,1]
    at = roc_auc_score(Y_Train, Y_Predicted)
    AUC_Train.append(at)
    lt = log_loss(Y_Train, Y_Predicted)
    loss_Train.append(lt)
    F1t = f1_score(Y_Train, y_Predicted, average='weighted')
    F1_Train.append(F1t)
    temp = temp*10

# %%
#plotting hyperparameter AUC curve 
x_axis = [-4, -3, -2, -1, 0, 1, 2, 3, 4]
plt.plot(x_axis, AUC_CV, label='Validation AUC')
plt.plot(x_axis, AUC_Train, label='Train AUC')
plt.xlabel('Hyperparameter')
plt.ylabel('Area under ROC curve')
plt.title("HyperParameter Tuning Curve (AUC)")
plt.legend()

# %%
#plotting hyperparameter Log-Loss curve 
x_axis = [-4, -3, -2, -1, 0, 1, 2, 3, 4]
plt.plot(x_axis, loss_CV, label='Validation loss')
plt.plot(x_axis, loss_Train, label='Train loss')
plt.xlabel('Hyperparameter')
plt.ylabel('Log-Loss curve')
plt.title("HyperParameter Tuning Curve (Log-Loss)")
plt.legend()

# %%
#plotting hyperparameter F1-Score curve 
x_axis = [-4, -3, -2, -1, 0, 1, 2, 3, 4]
plt.plot(x_axis, F1_CV, label='Validation F1-Score')
plt.plot(x_axis, F1_Train, label='Train F1-Score')
plt.xlabel('Hyperparameter')
plt.ylabel('F1-Score curve')
plt.title("HyperParameter Tuning Curve (F1-Score)")
plt.legend()

# %% [markdown]
# __The Best HyperParameter is var_smoothing = 10__

# %%
#Training model with var_smoothing = 10
clf = GaussianNB(var_smoothing = 10, priors=[0.5,0.5])
clf.fit(X_Train, Y_Train)
Y_Predicted_Train = clf.predict_proba(X_Train)
Y_Predicted_Train = Y_Predicted_Train[:,-1]
Y_Predicted_Test = clf.predict_proba(X_Test)
Y_Predicted_Test = Y_Predicted_Test[:,-1]

# %%
# Calculating the ROC values  
#https://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_curve.html
fpr_Train, tpr_Train, thresholds_Train = roc_curve(Y_Train, Y_Predicted_Train)
fpr_Test, tpr_Test, thresholds_Test = roc_curve(Y_Test, Y_Predicted_Test)

# %%
#Plotting ROC Curve
plt.plot(fpr_Test, tpr_Test, label='Test ROC')
plt.plot(fpr_Train, tpr_Train, label='Train ROC')
plt.plot([0,1], [0,1], label='Random ROC')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.title("AUC-ROC Curve")
plt.legend()

# %%
#printing kpi values
print('The auc is: ',roc_auc_score(Y_Test, Y_Predicted_Test))
print('The log loss is: ',log_loss(Y_Test, Y_Predicted_Test))
y_Predicted_Test = clf.predict(X_Test)
print('The F1-Score is: ',f1_score(Y_Test, y_Predicted_Test, average='weighted'))
# Out:
# The auc is:  0.8405276623388882
# The log loss is:  0.3843004800978188
# The F1-Score is:  0.8785229293159207

# %%
#initialize some values for future use
nb_auc = roc_auc_score(Y_Test, Y_Predicted_Test)
nb_loss = log_loss(Y_Test, Y_Predicted_Test)
nb_f1_score = f1_score(Y_Test, y_Predicted_Test, average='weighted')

# %%
#printing Confusion Matrix
Y_Predicted_Test =np.array(Y_Predicted_Test>0.5,dtype=int)
print("Total number of data points :", len(Y_Predicted_Test))
plot_confusion_matrix(Y_Test, Y_Predicted_Test)
# Out:
# Total number of data points : 12353

# %% [markdown]
# __Conclusions__
#
# - The model performs reasonably well with f1_score = 0.8785
# - The True Negative values are high
# - The True Positive values are decent
# - The False Negatives are high which is bad
# - The False Positives are high which is bad

# %% [markdown]
# ### Linear SVM

# %%
AUC_Train = []
AUC_CV = []
AUC_Test = []

loss_Train = []
loss_CV = []
loss_Test = []

F1_Train = []
F1_CV = []
F1_Test = []

#hyperparameter tuning for Linear SVM
hp = [-9,-8,-7,-6,-5,-4,-3,-2,-1]
for j in hp:
    c = 10**j
    clf_base = SGDClassifier(loss='hinge', penalty='l1', alpha = c, class_weight = 'balanced', n_jobs = -1)
    clf = CalibratedClassifierCV(clf_base, method='isotonic')
    clf.fit(X_Train, Y_Train)
    Y_Predicted = clf.predict_proba(X_CV)
    y_Predicted = clf.predict(X_CV)
    Y_Predicted = Y_Predicted[:,1]
    acv = roc_auc_score(Y_CV, Y_Predicted)
    AUC_CV.append(acv)
    lcv = log_loss(Y_CV, Y_Predicted)
    loss_CV.append(lcv)
    F1cv = f1_score(Y_CV, y_Predicted, average='weighted')
    F1_CV.append(F1cv)
    Y_Predicted = clf.predict_proba(X_Train)
    y_Predicted = clf.predict(X_Train)
    Y_Predicted = Y_Predicted[:,1]
    at = roc_auc_score(Y_Train, Y_Predicted)
    AUC_Train.append(at)
    lt = log_loss(Y_Train, Y_Predicted)
    loss_Train.append(lt)
    F1t = f1_score(Y_Train, y_Predicted, average='weighted')
    F1_Train.append(F1t)

# %%
#plotting hyperparameter AUC curve 
x_axis = [-9,-8,-7,-6,-5,-4,-3,-2,-1]
plt.plot(x_axis, AUC_CV, label='Validation AUC')
plt.plot(x_axis, AUC_Train, label='Train AUC')
plt.xlabel('Hyperparameter')
plt.ylabel('Area under ROC curve')
plt.title("HyperParameter Tuning Curve (AUC)")
plt.legend()

# %%
#plotting hyperparameter Log-Loss curve 
x_axis = [-9,-8,-7,-6,-5,-4,-3,-2,-1]
plt.plot(x_axis, loss_CV, label='Validation loss')
plt.plot(x_axis, loss_Train, label='Train loss')
plt.xlabel('Hyperparameter')
plt.ylabel('Log-Loss curve')
plt.title("HyperParameter Tuning Curve (Log-Loss)")
plt.legend()

# %%
#plotting hyperparameter F1-Score curve 
x_axis = [-9,-8,-7,-6,-5,-4,-3,-2,-1]
plt.plot(x_axis, F1_CV, label='Validation F1-Score')
plt.plot(x_axis, F1_Train, label='Train F1-Score')
plt.xlabel('Hyperparameter')
plt.ylabel('F1-Score curve')
plt.title("HyperParameter Tuning Curve (F1-Score)")
plt.legend()

# %% [markdown]
# __The best hyperparameter for Linear SVM is 0.001__

# %%
#Training model with c = 0.001
clf_base = SGDClassifier(loss='hinge', penalty='l1', alpha = 0.001, class_weight = 'balanced', n_jobs = -1)
clf = CalibratedClassifierCV(clf_base, method='isotonic')
clf.fit(X_Train, Y_Train)
Y_Predicted_Train = clf.predict_proba(X_Train)
Y_Predicted_Train = Y_Predicted_Train[:,-1]
Y_Predicted_Test = clf.predict_proba(X_Test)
Y_Predicted_Test = Y_Predicted_Test[:,-1]

# %%
# Calculating the ROC values  
#https://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_curve.html
fpr_Train, tpr_Train, thresholds_Train = roc_curve(Y_Train, Y_Predicted_Train)
fpr_Test, tpr_Test, thresholds_Test = roc_curve(Y_Test, Y_Predicted_Test)

# %%
#Plotting ROC Curve
plt.plot(fpr_Test, tpr_Test, label='Test ROC')
plt.plot(fpr_Train, tpr_Train, label='Train ROC')
plt.plot([0,1], [0,1], label='Random ROC')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.title("AUC-ROC Curve")
plt.legend()

# %%
#printing the KPI values
print('The auc is: ',roc_auc_score(Y_Test, Y_Predicted_Test))
print('The log loss is: ',log_loss(Y_Test, Y_Predicted_Test))
y_Predicted_Test = clf.predict(X_Test)
print('The F1-Score is: ',f1_score(Y_Test, y_Predicted_Test, average='weighted'))
# Out:
# The auc is:  0.9331520676232451
# The log loss is:  0.19427328225050272
# The F1-Score is:  0.9053966701169085

# %%
#initializing some values for further use
svm_auc = roc_auc_score(Y_Test, Y_Predicted_Test)
svm_loss = log_loss(Y_Test, Y_Predicted_Test)
svm_f1_score = f1_score(Y_Test, y_Predicted_Test, average='weighted')

# %%
#printing the Confusion Matrix
Y_Predicted_Test =np.array(Y_Predicted_Test>0.5,dtype=int)
print("Total number of data points :", len(Y_Predicted_Test))
plot_confusion_matrix(Y_Test, Y_Predicted_Test)
# Out:
# Total number of data points : 12353

# %% [markdown]
# __Conclusions__
#
# - The model performs reasonably well with f1_score = 0.9053
# - The True Negative values are high
# - The True Positive values are decent
# - The False Negatives are high which is bad
# - The False Positives are high which is bad

# %% [markdown]
# ### Decision Tree

# %%
#Finding best Hyperparamer
AUC_Train = []
AUC_CV = []
AUC_Test = []

loss_Train = []
loss_CV = []
loss_Test = []

F1_Train = []
F1_CV = []
F1_Test = []
    
#hyperparameter tuning for Decision Tree
depth = [1,2,3,5,8,13]
for d in depth:
    clf = DecisionTreeClassifier(max_depth=d, class_weight = 'balanced')
    clf.fit(X_Train, Y_Train)
    Y_Predicted = clf.predict_proba(X_CV)
    y_Predicted = clf.predict(X_CV)
    Y_Predicted = Y_Predicted[:,1]
    acv = roc_auc_score(Y_CV, Y_Predicted)
    AUC_CV.append(acv)
    lcv = log_loss(Y_CV, Y_Predicted)
    loss_CV.append(lcv)
    F1cv = f1_score(Y_CV, y_Predicted, average='weighted')
    F1_CV.append(F1cv)
    Y_Predicted = clf.predict_proba(X_Train)
    y_Predicted = clf.predict(X_Train)
    Y_Predicted = Y_Predicted[:,1]
    at = roc_auc_score(Y_Train, Y_Predicted)
    AUC_Train.append(at)
    lt = log_loss(Y_Train, Y_Predicted)
    loss_Train.append(lt)
    F1t = f1_score(Y_Train, y_Predicted, average='weighted')
    F1_Train.append(F1t)

# %%
#plotting hyperparameter AUC curve 
x_axis = [1,2,3,5,8,13]
plt.plot(x_axis, AUC_CV, label='Validation AUC')
plt.plot(x_axis, AUC_Train, label='Train AUC')
plt.xlabel('Hyperparameter')
plt.ylabel('Area under ROC curve')
plt.title("HyperParameter Tuning Curve (AUC)")
plt.legend()

# %%
#plotting hyperparameter Log-Loss curve 
x_axis = [1,2,3,5,8,13]
plt.plot(x_axis, loss_CV, label='Validation loss')
plt.plot(x_axis, loss_Train, label='Train loss')
plt.xlabel('Hyperparameter')
plt.ylabel('Log-Loss curve')
plt.title("HyperParameter Tuning Curve (Log-Loss)")
plt.legend()

# %%
#plotting hyperparameter F1-Score curve 
x_axis = [1,2,3,5,8,13]
plt.plot(x_axis, F1_CV, label='Validation F1-Score')
plt.plot(x_axis, F1_Train, label='Train F1-Score')
plt.xlabel('Hyperparameter')
plt.ylabel('F1-Score curve')
plt.title("HyperParameter Tuning Curve (F1-Score)")
plt.legend()

# %% [markdown]
# __The best HyperParameter for Dedision Tree is d = 5__

# %%
#Training model with d = 5
clf = DecisionTreeClassifier(max_depth=5, class_weight = 'balanced')
clf.fit(X_Train, Y_Train)
Y_Predicted_Train = clf.predict_proba(X_Train)
Y_Predicted_Train = Y_Predicted_Train[:,-1]
Y_Predicted_Test = clf.predict_proba(X_Test)
Y_Predicted_Test = Y_Predicted_Test[:,-1]

# %%
# Calculating the ROC values  
#https://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_curve.html
fpr_Train, tpr_Train, thresholds_Train = roc_curve(Y_Train, Y_Predicted_Train)
fpr_Test, tpr_Test, thresholds_Test = roc_curve(Y_Test, Y_Predicted_Test)

# %%
#Plotting ROC Curve
plt.plot(fpr_Test, tpr_Test, label='Test ROC')
plt.plot(fpr_Train, tpr_Train, label='Train ROC')
plt.plot([0,1], [0,1], label='Random ROC')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.title("AUC-ROC Curve")
plt.legend()

# %%
#Printing the KPI values
print('The auc is: ',roc_auc_score(Y_Test, Y_Predicted_Test))
print('The log loss is: ',log_loss(Y_Test, Y_Predicted_Test))
y_Predicted_Test = clf.predict(X_Test)
print('The F1-Score is: ',f1_score(Y_Test, y_Predicted_Test, average='weighted'))
# Out:
# The auc is:  0.9254260402870365
# The log loss is:  0.34951227864589596
# The F1-Score is:  0.8656632481986147

# %%
#initializing sone variables for future use__
dt_auc = roc_auc_score(Y_Test, Y_Predicted_Test)
dt_loss = log_loss(Y_Test, Y_Predicted_Test)
dt_f1_score = f1_score(Y_Test, y_Predicted_Test, average='weighted')

# %%
Y_Predicted_Test =np.array(Y_Predicted_Test>0.5,dtype=int)
print("Total number of data points :", len(Y_Predicted_Test))
plot_confusion_matrix(Y_Test, Y_Predicted_Test)
# Out:
# Total number of data points : 12353

# %% [markdown]
# __Conclusions__
#
# - The model performs reasonably well with f1_score = 0.8656
# - The True Negative values are high
# - The True Positive values are decent
# - The False Negatives are low
# - The False Positives are very high which is bad

# %% [markdown]
# ### Random Forest

# %%
#Finding best Hyperparameter
depth = [1,2,3,5,8,13]
estimators = [50,100,200,300,400]
heat_map_data_cv_auc = np.zeros((30,3))
heat_map_data_train_auc = np.zeros((30,3))
heat_map_data_cv_loss = np.zeros((30,3))
heat_map_data_train_loss = np.zeros((30,3))
heat_map_data_cv_F1 = np.zeros((30,3))
heat_map_data_train_F1 = np.zeros((30,3))

#hyperparameter tuning for Random Forest
i = 0
for k in estimators:
    for d in depth:
        clf = RandomForestClassifier(n_estimators=k ,max_depth=d, 
                                     class_weight='balanced', bootstrap=True, n_jobs = -1)
        clf.fit(X_Train, Y_Train)
        Y_Predicted = clf.predict_proba(X_CV)
        y_Predicted = clf.predict(X_CV)
        Y_Predicted = Y_Predicted[:,1]
        acv = roc_auc_score(Y_CV, Y_Predicted)
        lcv = log_loss(Y_CV, Y_Predicted)
        F1cv = f1_score(Y_CV, y_Predicted, average='weighted')
        AUC_CV.append(acv)
        Y_Predicted = clf.predict_proba(X_Train)
        y_Predicted = clf.predict(X_Train)
        Y_Predicted = Y_Predicted[:,1]
        atr = roc_auc_score(Y_Train, Y_Predicted)
        ltr = log_loss(Y_Train, Y_Predicted)
        F1tr = f1_score(Y_Train, y_Predicted, average='weighted')
        AUC_Train.append(atr)
        
        heat_map_data_cv_auc[i][0] = k
        heat_map_data_cv_auc[i][1] = d
        heat_map_data_cv_auc[i][2] = acv
        heat_map_data_train_auc[i][0] = k
        heat_map_data_train_auc[i][1] = d
        heat_map_data_train_auc[i][2] = atr
        
        heat_map_data_cv_loss[i][0] = k
        heat_map_data_cv_loss[i][1] = d
        heat_map_data_cv_loss[i][2] = lcv
        heat_map_data_train_loss[i][0] = k
        heat_map_data_train_loss[i][1] = d
        heat_map_data_train_loss[i][2] = ltr
        
        heat_map_data_cv_F1[i][0] = k
        heat_map_data_cv_F1[i][1] = d
        heat_map_data_cv_F1[i][2] = F1cv
        heat_map_data_train_F1[i][0] = k
        heat_map_data_train_F1[i][1] = d
        heat_map_data_train_F1[i][2] = F1tr
        i+=1
        print('Iteration = ',i,' Estimators = ',k, 'max_depth = ', d, 'Train Score', F1tr, 'CV Score', F1cv)
# Out:
# Iteration =  1  Estimators =  50 max_depth =  1 Train Score 0.8313135095789954 CV Score 0.8324292038816091
# Iteration =  2  Estimators =  50 max_depth =  2 Train Score 0.8420281734753784 CV Score 0.8426030217912432
# Iteration =  3  Estimators =  50 max_depth =  3 Train Score 0.8622188840290189 CV Score 0.8614474323429584
# Iteration =  4  Estimators =  50 max_depth =  5 Train Score 0.8639384357904535 CV Score 0.8613476061569664
# Iteration =  5  Estimators =  50 max_depth =  8 Train Score 0.884967737720213 CV Score 0.8740846019553288
# Iteration =  6  Estimators =  50 max_depth =  13 Train Score 0.9489180650759175 CV Score 0.9062744060565999
# Iteration =  7  Estimators =  100 max_depth =  1 Train Score 0.8485024102586282 CV Score 0.849044477662514
# Iteration =  8  Estimators =  100 max_depth =  2 Train Score 0.8443324901608575 CV Score 0.8448472487475881
# Iteration =  9  Estimators =  100 max_depth =  3 Train Score 0.8551464201026321 CV Score 0.8546627087304759
# ...

# %% [markdown]
# __The best Hyper Parameter for the Random Forest Classifier are estimators = 200 and depth = 13__

# %%
#Training Model with estimators =200 and depth = 13
clf = RandomForestClassifier(n_estimators=200 ,max_depth=13, class_weight='balanced', bootstrap=True, n_jobs = -1)
clf.fit(X_Train, Y_Train)
Y_Predicted_Train = clf.predict_proba(X_Train)
Y_Predicted_Train = Y_Predicted_Train[:,-1]
Y_Predicted_Test = clf.predict_proba(X_Test)
Y_Predicted_Test = Y_Predicted_Test[:,-1]

# Calculating the ROC values  
fpr_Train, tpr_Train, thresholds_Train = roc_curve(Y_Train, Y_Predicted_Train)
fpr_Test, tpr_Test, thresholds_Test = roc_curve(Y_Test, Y_Predicted_Test)

#Plotting ROC Curve
plt.plot(fpr_Test, tpr_Test, label='Test ROC')
plt.plot(fpr_Train, tpr_Train, label='Train ROC')
plt.plot([0,1], [0,1], label='Random ROC')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.title("AUC-ROC Curve")
plt.legend()

# %%
print('The auc is: ',roc_auc_score(Y_Test, Y_Predicted_Test))
print('The log loss is: ',log_loss(Y_Test, Y_Predicted_Test))
y_Predicted_Test = clf.predict(X_Test)
print('The F1-Score is: ',f1_score(Y_Test, y_Predicted_Test, average='weighted'))
# Out:
# The auc is:  0.9422136818416811
# The log loss is:  0.23596752999415757
# The F1-Score is:  0.9074112912112907

# %%
#Initializing some variables for future use
rf_auc = roc_auc_score(Y_Test, Y_Predicted_Test)
rf_loss = log_loss(Y_Test, Y_Predicted_Test)
rf_f1_score = f1_score(Y_Test, y_Predicted_Test, average='weighted')

# %%
Y_Predicted_Test =np.array(Y_Predicted_Test>0.5,dtype=int)
print("Total number of data points :", len(Y_Predicted_Test))
plot_confusion_matrix(Y_Test, Y_Predicted_Test)
# Out:
# Total number of data points : 12353

# %% [markdown]
# __Conclusions__
#
# - The model performs reasonably well with f1_score = 0.9074
# - The True Negative values are high
# - The True Positive values are decent
# - The False Negatives are decent
# - The False Positives are high which is bad

# %% [markdown]
# ###  XGBoost

# %%
#Hyperparameter tuning

max_depth = [1,2,3,5,8]
n_estimators = [1,5,10,50,100,150,200,250]
heat_map_data_cv_auc = np.zeros((40,3))
heat_map_data_train_auc = np.zeros((40,3))
heat_map_data_cv_loss = np.zeros((40,3))
heat_map_data_train_loss = np.zeros((40,3))
heat_map_data_cv_F1 = np.zeros((40,3))
heat_map_data_train_F1 = np.zeros((40,3))

i = 0
for n in n_estimators:
    for d in max_depth:
        clf = xgb.XGBRFClassifier(n_estimators=n, learning_rate=0.8, max_depth=d, class_weight='balanced')
        clf.fit(X_Train, Y_Train)
        Y_Predicted = clf.predict_proba(X_CV)
        y_Predicted = clf.predict(X_CV)
        Y_Predicted = Y_Predicted[:,1]
        acv = roc_auc_score(Y_CV, Y_Predicted)
        lcv = log_loss(Y_CV, Y_Predicted)
        F1cv = f1_score(Y_CV, y_Predicted, average='weighted')
        AUC_CV.append(acv)
        Y_Predicted = clf.predict_proba(X_Train)
        y_Predicted = clf.predict(X_Train)
        Y_Predicted = Y_Predicted[:,1]
        atr = roc_auc_score(Y_Train, Y_Predicted)
        ltr = log_loss(Y_Train, Y_Predicted)
        F1tr = f1_score(Y_Train, y_Predicted, average='weighted')
        AUC_Train.append(atr)
        print('Iteration = ',i,' Estimators = ',n, 'max_depth = ', d, 'Train Score', F1tr, 'CV Score', F1cv)
        
        heat_map_data_cv_auc[i][0] = n
        heat_map_data_cv_auc[i][1] = d
        heat_map_data_cv_auc[i][2] = acv
        heat_map_data_train_auc[i][0] = n
        heat_map_data_train_auc[i][1] = d
        heat_map_data_train_auc[i][2] = atr
        
        heat_map_data_cv_loss[i][0] = n
        heat_map_data_cv_loss[i][1] = d
        heat_map_data_cv_loss[i][2] = lcv
        heat_map_data_train_loss[i][0] = n
        heat_map_data_train_loss[i][1] = d
        heat_map_data_train_loss[i][2] = ltr
        
        heat_map_data_cv_F1[i][0] = n
        heat_map_data_cv_F1[i][1] = d
        heat_map_data_cv_F1[i][2] = F1cv
        heat_map_data_train_F1[i][0] = n
        heat_map_data_train_F1[i][1] = d
        heat_map_data_train_F1[i][2] = F1tr
        i+=1
# Out:
# Iteration =  0  Estimators =  1 max_depth =  1 Train Score 0.8343744850197591 CV Score 0.834400928464366
# Iteration =  1  Estimators =  1 max_depth =  2 Train Score 0.8729181748556818 CV Score 0.8704246368996577
# Iteration =  2  Estimators =  1 max_depth =  3 Train Score 0.90102381308755 CV Score 0.896165610731377
# Iteration =  3  Estimators =  1 max_depth =  5 Train Score 0.9116513185003352 CV Score 0.902344298212883
# Iteration =  4  Estimators =  1 max_depth =  8 Train Score 0.9275748948972244 CV Score 0.9008527851262065
# Iteration =  5  Estimators =  5 max_depth =  1 Train Score 0.8343744850197591 CV Score 0.834400928464366
# Iteration =  6  Estimators =  5 max_depth =  2 Train Score 0.8729527942320238 CV Score 0.8706320294802028
# Iteration =  7  Estimators =  5 max_depth =  3 Train Score 0.90102381308755 CV Score 0.8963218297895712
# Iteration =  8  Estimators =  5 max_depth =  5 Train Score 0.9137315473294118 CV Score 0.9053566074551355
# ...

# %% [markdown]
# __The Best HyperParameters are n_estimators = 250 and d = 5__

# %%
#Training Model with estimators = 250 and depth = 5
clf = xgb.XGBRFClassifier(n_estimators=250 ,max_depth=5, class_weight='balanced', bootstrap=True, n_jobs = -1)
clf.fit(X_Train, Y_Train)
Y_Predicted_Train = clf.predict_proba(X_Train)
Y_Predicted_Train = Y_Predicted_Train[:,-1]
Y_Predicted_Test = clf.predict_proba(X_Test)
Y_Predicted_Test = Y_Predicted_Test[:,-1]

# Calculating the ROC values  
fpr_Train, tpr_Train, thresholds_Train = roc_curve(Y_Train, Y_Predicted_Train)
fpr_Test, tpr_Test, thresholds_Test = roc_curve(Y_Test, Y_Predicted_Test)

#Plotting ROC Curve
plt.plot(fpr_Test, tpr_Test, label='Test ROC')
plt.plot(fpr_Train, tpr_Train, label='Train ROC')
plt.plot([0,1], [0,1], label='Random ROC')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.title("AUC-ROC Curve")
plt.legend()

# %%
#Printing the KPI values
print('The auc is: ',roc_auc_score(Y_Test, Y_Predicted_Test))
print('The log loss is: ',log_loss(Y_Test, Y_Predicted_Test))
y_Predicted_Test = clf.predict(X_Test)
print('The F1-Score is: ',f1_score(Y_Test, y_Predicted_Test, average='weighted'))
# Out:
# The auc is:  0.9371457529149849
# The log loss is:  0.26402837308849736
# The F1-Score is:  0.9111923284388074

# %%
#Initializing variables for future use
xgb_auc = roc_auc_score(Y_Test, Y_Predicted_Test)
xgb_loss = log_loss(Y_Test, Y_Predicted_Test)
xgb_f1_score = f1_score(Y_Test, y_Predicted_Test, average='weighted')

# %%
#Plot the Confusion Matrix
predicted_y = np.array(Y_Predicted_Test > 0.5, dtype=int)
print("Total number of data points :", len(Y_Predicted_Test))
plot_confusion_matrix(Y_Test, y_Predicted_Test)
# Out:
# Total number of data points : 12353

# %% [markdown]
# __Conclusions__
#
# - The model performs reasonably well with f1_score = 0.9111
# - The True Negative values are high
# - The True Positive values are decent
# - The False Negatives are slightly high which is bad
# - The False Positives are slightly high which is bad

# %% [markdown]
# ### Simple Neural Network(With 1 layer)

# %%
from keras.utils import plot_model
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
#define the layers
input_layer = Input(shape=(81, ))
hidden_layer = Dense(4, activation='relu')(input_layer)
hidden_layer = Dropout(0.2)(hidden_layer)
output_layer = Dense(1, activation='sigmoid')(hidden_layer)
model = Model(inputs=input_layer, outputs=output_layer)
# summarize layers
print(model.summary())
#compiling model
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['acc'])
#fitting model
history = model.fit(X_Train,
                    Y_Train,
                    validation_data=(X_CV, Y_CV),
                    epochs=40,
                    shuffle="batch",
                    batch_size=128)
# Out:
# WARNING:tensorflow:From /home/shashank/0_Zero_All_Files/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, 81)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 328
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4)                 0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 5
# ...

# %%
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
#getting the KPI values
Y_Predicted_Train = model.predict(X_Train)
Y_Predicted_Train = Y_Predicted_Train[:,-1]
Y_Predicted_Test = model.predict(X_Test)
Y_Predicted_Test = Y_Predicted_Test[:,-1]

# Calculating the ROC values  
fpr_Train, tpr_Train, thresholds_Train = roc_curve(Y_Train, Y_Predicted_Train)
fpr_Test, tpr_Test, thresholds_Test = roc_curve(Y_Test, Y_Predicted_Test)

#Plotting ROC Curve
plt.plot(fpr_Test, tpr_Test, label='Test ROC')
plt.plot(fpr_Train, tpr_Train, label='Train ROC')
plt.plot([0,1], [0,1], label='Random ROC')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.title("AUC-ROC Curve")
plt.legend()

# %%
#Printing the KPI values
print('The auc is: ',roc_auc_score(Y_Test, Y_Predicted_Test))
print('The log loss is: ',log_loss(Y_Test, Y_Predicted_Test))
y_Predicted_Test = np.array(Y_Predicted_Test > 0.5, dtype=int)
print('The F1-Score is: ',f1_score(Y_Test, y_Predicted_Test, average='weighted'))
# Out:
# The auc is:  0.9387072583359812
# The log loss is:  0.19205231995362704
# The F1-Score is:  0.8958078840833328

# %%
#Initializing variables for future use
mlp_auc = roc_auc_score(Y_Test, Y_Predicted_Test)
mlp_loss = log_loss(Y_Test, Y_Predicted_Test)
mlp_f1_score = f1_score(Y_Test, y_Predicted_Test, average='weighted')

# %%
#Plot the Confusion Matrix
predicted_y = np.array(Y_Predicted_Test > 0.5, dtype=int)
print("Total number of data points :", len(Y_Predicted_Test))
plot_confusion_matrix(Y_Test, y_Predicted_Test)
# Out:
# Total number of data points : 12353

# %% [markdown]
# __Conclusions__
#
# - The model performs reasonably well with f1_score = 0.8959
# - The True Negative values are high
# - The True Positive values are very less
# - The False Negatives are very high which is bad
# - The False Positives decent

# %% [markdown]
# ### Stacking Classifier

# %% [markdown]
# __In the stacking Classifier we are considering only those models whose Precession and recall values for positive class is high__

# %%
#lets define the stacking classifier and then we will tune the hyperparameter
from mlxtend.classifier import StackingClassifier
#defining the base classifiers
lr = LogisticRegression(C = 0.001, class_weight = 'balanced', random_state=42)
rf = RandomForestClassifier(n_estimators=200 ,max_depth=13, class_weight='balanced', bootstrap=True, n_jobs = -1, random_state=42)
dt = DecisionTreeClassifier(max_depth=5, class_weight = 'balanced', random_state=42)
clf_base = SGDClassifier(loss='hinge', penalty='l1', alpha = 0.001, class_weight = 'balanced', n_jobs = -1, random_state=42)
svm = CalibratedClassifierCV(clf_base, method='isotonic')
xgboost = xgb.XGBRFClassifier(n_estimators=250 ,max_depth=5, class_weight='balanced', bootstrap=True, n_jobs = -1, random_state=42)

# %%
AUC_Train = []
AUC_CV = []
AUC_Test = []

loss_Train = []
loss_CV = []
loss_Test = []

F1_Train = []
F1_CV = []
F1_Test = []

#code for hyperparameter tuning the logistic regression in the stacking classifier
c = 0.00001
for i in range(1,9):
    meta_clf = LogisticRegression(C=c, class_weight='balanced', random_state=42)
    sclf = StackingClassifier(classifiers=[lr, rf, dt, svm, xgboost],
                            meta_classifier=meta_clf)
    sclf.fit(X_Train, Y_Train)
    Y_Predicted = sclf.predict_proba(X_CV)
    y_Predicted = sclf.predict(X_CV)
    Y_Predicted = Y_Predicted[:,1]
    acv = roc_auc_score(Y_CV, Y_Predicted)
    AUC_CV.append(acv)
    lcv = log_loss(Y_CV, Y_Predicted)
    loss_CV.append(lcv)
    F1cv = f1_score(Y_CV, y_Predicted, average='weighted')
    F1_CV.append(F1cv)
    Y_Predicted = sclf.predict_proba(X_Train)
    y_Predicted = sclf.predict(X_Train)
    Y_Predicted = Y_Predicted[:,1]
    at = roc_auc_score(Y_Train, Y_Predicted)
    AUC_Train.append(at)
    lt = log_loss(Y_Train, Y_Predicted)
    loss_Train.append(lt)
    F1t = f1_score(Y_Train, y_Predicted, average='weighted')
    F1_Train.append(F1t)
    c = c*10

# %%
#plotting hyperparameter AUC curve 
x_axis = [-5, -4, -3, -2, -1, 0, 1, 2]
plt.plot(x_axis, AUC_CV, label='Validation AUC')
plt.plot(x_axis, AUC_Train, label='Train AUC')
plt.xlabel('Hyperparameter')
plt.ylabel('Area under ROC curve')
plt.title("HyperParameter Tuning Curve (AUC)")
plt.legend()

# %%
#plotting hyperparameter Log-Loss curve 
x_axis = [-5, -4, -3, -2, -1, 0, 1, 2]
plt.plot(x_axis, loss_CV, label='Validation loss')
plt.plot(x_axis, loss_Train, label='Train loss')
plt.xlabel('Hyperparameter')
plt.ylabel('Log-Loss curve')
plt.title("HyperParameter Tuning Curve (Log-Loss)")
plt.legend()

# %%
#plotting hyperparameter F1-Score curve 
x_axis = [-5, -4, -3, -2, -1, 0, 1, 2]
plt.plot(x_axis, F1_CV, label='Validation F1-Score')
plt.plot(x_axis, F1_Train, label='Train F1-Score')
plt.xlabel('Hyperparameter')
plt.ylabel('F1-Score curve')
plt.title("HyperParameter Tuning Curve (F1-Score)")
plt.legend()

# %% [markdown]
# __The Best Hyperparameter is 0.01__

# %%
#lets define the stacking classifier and then we will tune the hyperparameter
from mlxtend.classifier import StackingClassifier
#defining the base classifiers
lr = LogisticRegression(C = 0.001, class_weight = 'balanced', random_state=42)
rf = RandomForestClassifier(n_estimators=200 ,max_depth=13, class_weight='balanced', bootstrap=True, n_jobs = -1, random_state=42)
dt = DecisionTreeClassifier(max_depth=5, class_weight = 'balanced', random_state=42)
clf_base = SGDClassifier(loss='hinge', penalty='l1', alpha = 0.001, class_weight = 'balanced', n_jobs = -1, random_state=42)
svm = CalibratedClassifierCV(clf_base, method='isotonic')
xgboost = xgb.XGBRFClassifier(n_estimators=250 ,max_depth=5, class_weight='balanced', bootstrap=True, n_jobs = -1, random_state=42)
#Tuning the meta classifier with best hyperparameter
meta_clf = LogisticRegression(C=0.01, class_weight='balanced', random_state=42)
sclf = StackingClassifier(classifiers=[lr, rf, dt, svm, xgboost], meta_classifier=meta_clf)
sclf.fit(X_Train, Y_Train)
# Out:
# StackingClassifier(average_probas=False,
#                    classifiers=[LogisticRegression(C=0.001,
#                                                    class_weight='balanced',
#                                                    dual=False,
#                                                    fit_intercept=True,
#                                                    intercept_scaling=1,
#                                                    l1_ratio=None, max_iter=100,
#                                                    multi_class='warn',
#                                                    n_jobs=None, penalty='l2',
#                                                    random_state=42,
#                                                    solver='warn', tol=0.0001,
#                                                    verbose=0,
#                                                    warm_start=False),
#                                 RandomForestClassifier(bootstrap=True,
# ...

# %%
#getting the KPI values
Y_Predicted_Train = sclf.predict_proba(X_Train)
Y_Predicted_Train = Y_Predicted_Train[:,-1]
Y_Predicted_Test = sclf.predict_proba(X_Test)
Y_Predicted_Test = Y_Predicted_Test[:,-1]

# Calculating the ROC values  
fpr_Train, tpr_Train, thresholds_Train = roc_curve(Y_Train, Y_Predicted_Train)
fpr_Test, tpr_Test, thresholds_Test = roc_curve(Y_Test, Y_Predicted_Test)

#Plotting ROC Curve
plt.plot(fpr_Test, tpr_Test, label='Test ROC')
plt.plot(fpr_Train, tpr_Train, label='Train ROC')
plt.plot([0,1], [0,1], label='Random ROC')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.title("AUC-ROC Curve")
plt.legend()

# %%
#Printing the KPI values
print('The auc is: ',roc_auc_score(Y_Test, Y_Predicted_Test))
print('The log loss is: ',log_loss(Y_Test, Y_Predicted_Test))
y_Predicted_Test = np.array(Y_Predicted_Test > 0.5, dtype=int)
print('The F1-Score is: ',f1_score(Y_Test, y_Predicted_Test, average='weighted'))
# Out:
# The auc is:  0.969419563038023
# The log loss is:  0.21984594218898387
# The F1-Score is:  0.9569795456555172

# %%
#Initializing variables for future use
stack_auc = roc_auc_score(Y_Test, Y_Predicted_Test)
stack_loss = log_loss(Y_Test, Y_Predicted_Test)
stack_f1_score = f1_score(Y_Test, y_Predicted_Test, average='weighted')

# %%
#Plot the Confusion Matrix
predicted_y = np.array(Y_Predicted_Test > 0.5, dtype=int)
print("Total number of data points :", len(Y_Predicted_Test))
plot_confusion_matrix(Y_Test, y_Predicted_Test)
# Out:
# Total number of data points : 12353

# %% [markdown]
# __Conclusions__
#
# - The model performs reasonably well with f1_score = 0.9569
# - The True Negative values are high
# - The True Positive values are decent
# - The False Negatives are less
# - The False Positives are decent

# %% [markdown]
# ### Voting Classifier

# %% [markdown]
# __In the Voting Classifier we are considering only those models whose Precession and recall values for positive class is high__

# %%
#For the voting and the stacking classifier we need to combine the train and cv data
X_Train_Ensemble = sparse.vstack((X_Train,X_CV)).toarray()
Y_Train_Ensemble = sparse.vstack((Y_Train,Y_CV)).toarray()

# %%
#using mlxtend as it was giving better results
from mlxtend.classifier import EnsembleVoteClassifier
#defining the base classifiers
lr = LogisticRegression(C = 0.001, class_weight = 'balanced', random_state=42)
rf = RandomForestClassifier(n_estimators=200 ,max_depth=13, class_weight='balanced', bootstrap=True, n_jobs = -1, random_state=42)
dt = DecisionTreeClassifier(max_depth=5, class_weight = 'balanced', random_state=42)
clf_base = SGDClassifier(loss='hinge', penalty='l1', alpha = 0.001, class_weight = 'balanced', n_jobs = -1, random_state=42)
svm = CalibratedClassifierCV(clf_base, method='isotonic')
xgboost = xgb.XGBRFClassifier(n_estimators=250 ,max_depth=5, class_weight='balanced', bootstrap=True, n_jobs = -1, random_state=42)
#voting classifier
eclf = EnsembleVoteClassifier(clfs=[lr, rf, dt, svm, xgboost], weights=[1, 1, 1, 5, 5], voting='soft')
eclf.fit(X_Train_Ensemble, Y_Train_Ensemble)
# Out:
# EnsembleVoteClassifier(clfs=[LogisticRegression(C=0.001,
#                                                 class_weight='balanced',
#                                                 dual=False, fit_intercept=True,
#                                                 intercept_scaling=1,
#                                                 l1_ratio=None, max_iter=100,
#                                                 multi_class='warn', n_jobs=None,
#                                                 penalty='l2', random_state=42,
#                                                 solver='warn', tol=0.0001,
#                                                 verbose=0, warm_start=False),
#                              RandomForestClassifier(bootstrap=True,
#                                                     class_weight='balanced',
#                                                     criterion='gini',
#                                                     m...
# ...

# %%
#getting the KPI values
Y_Predicted_Train = eclf.predict_proba(X_Train_Ensemble)
Y_Predicted_Train = Y_Predicted_Train[:,-1]
Y_Predicted_Test = eclf.predict_proba(X_Test)
Y_Predicted_Test = Y_Predicted_Test[:,-1]

# Calculating the ROC values  
fpr_Train, tpr_Train, thresholds_Train = roc_curve(Y_Train_Ensemble, Y_Predicted_Train)
fpr_Test, tpr_Test, thresholds_Test = roc_curve(Y_Test, Y_Predicted_Test)

#Plotting ROC Curve
plt.plot(fpr_Test, tpr_Test, label='Test ROC')
plt.plot(fpr_Train, tpr_Train, label='Train ROC')
plt.plot([0,1], [0,1], label='Random ROC')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.title("AUC-ROC Curve")
plt.legend()

# %%
#Printing the KPI values
print('The auc is: ',roc_auc_score(Y_Test, Y_Predicted_Test))
print('The log loss is: ',log_loss(Y_Test, Y_Predicted_Test))
y_Predicted_Test = np.array(Y_Predicted_Test > 0.5, dtype=int)
print('The F1-Score is: ',f1_score(Y_Test, y_Predicted_Test, average='weighted'))
# Out:
# The auc is:  0.9428196704722176
# The log loss is:  0.22760226074090412
# The F1-Score is:  0.9129966037799493

# %%
#Initializing variables for future use
vote_auc = roc_auc_score(Y_Test, Y_Predicted_Test)
vote_loss = log_loss(Y_Test, Y_Predicted_Test)
vote_f1_score = f1_score(Y_Test, y_Predicted_Test, average='weighted')

# %%
#Plot the Confusion Matrix
predicted_y = np.array(Y_Predicted_Test > 0.5, dtype=int)
print("Total number of data points :", len(Y_Predicted_Test))
plot_confusion_matrix(Y_Test, y_Predicted_Test)
# Out:
# Total number of data points : 12353

# %% [markdown]
# __Conclusions__
#
# - The model performs reasonably well with f1_score = 0.9129
# - The True Negative values are high
# - The True Positive values are decent
# - The False Negatives are high which is bad
# - The False Positives are high which is bad

# %% [markdown]
# ## Conclusions

# %%
from prettytable import PrettyTable
    
x = PrettyTable()

x.field_names = ["Model-name", "AUC", "Log-Loss", "F1-Score"]

x.add_row(["Logistic Regression", lr_auc, lr_loss, lr_f1_score])
x.add_row(["Naive Bayes", nb_auc, nb_loss, nb_f1_score])
x.add_row(["Linear SVM", svm_auc, svm_loss, svm_f1_score])
x.add_row(["Decission Tree", dt_auc, dt_loss, dt_f1_score])
x.add_row(["Random Forrest", rf_auc, rf_loss, rf_f1_score])
x.add_row(["XGBoost", xgb_auc, xgb_loss, xgb_f1_score])
x.add_row(["MLP", mlp_auc, mlp_loss, mlp_f1_score])
x.add_row(["Stacking Classifier", stack_auc, stack_loss, stack_f1_score])
x.add_row(["Voting Classifier", vote_auc, vote_loss, vote_f1_score])

print(x)
# Out:
# +---------------------+--------------------+---------------------+--------------------+
# |      Model-name     |        AUC         |       Log-Loss      |      F1-Score      |
# +---------------------+--------------------+---------------------+--------------------+
# | Logistic Regression | 0.9295261963261595 | 0.38209830415634705 | 0.8733040737184175 |
# |     Naive Bayes     | 0.8405276623388882 |  0.3843004800978188 | 0.8785229293159207 |
# |      Linear SVM     | 0.9331520676232451 | 0.19427328225050272 | 0.9053966701169085 |
# |    Decission Tree   | 0.9254260402870365 | 0.34951227864589596 | 0.8656632481986147 |
# |    Random Forrest   | 0.9422136818416811 | 0.23596752999415757 | 0.9074112912112907 |
# |       XGBoost       | 0.9371457529149849 | 0.26402837308849736 | 0.9111923284388074 |
# |         MLP         | 0.9387072583359812 | 0.19205231995362704 | 0.8958078840833328 |
# | Stacking Classifier | 0.969419563038023  | 0.21984594218898387 | 0.9569795456555172 |
# ...

# %% [markdown]
# - In this notebook EDA was performed
# - From the Table we see that Stacking Model Performs Best with weighted F1-Score of 0.9569
# - After comparing the Confusion Matrix for all the models, we can say that The Confusion Matrix of Stacking Model is the Best
# - Also the stacking Classifier has very less false negative values which is very good as the Model will not mark positive points as negative points and hence the Bank will not loose many genuine customers in the Marketing Process
# - The Precession for the positives points is 0.716 for the best Model and this means that Out of the Points that the model marked as Positive points around 70% of them are genuine

# %% [markdown]
# ## References

# %% [markdown]
# - Applied AI Course
# - https://www.kaggle.com/nextbigwhat/eda-for-categorical-variables-a-beginner-s-way
# - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.replace.html
# - https://seaborn.pydata.org/generated/seaborn.pairplot.html
# - https://www.geeksforgeeks.org/permutation-and-combination-in-python/
# - https://seaborn.pydata.org/examples/distplot_options.html
# - https://stackoverflow.com/questions/14770735/how-do-i-change-the-figure-size-with-subplots
# - https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html
# - https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html
# - https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelEncoder.html
# - https://towardsdatascience.com/how-to-visualize-a-decision-tree-in-5-steps-19781b28ffe2
# - https://towardsdatascience.com/visualizing-decision-trees-with-python-scikit-learn-graphviz-matplotlib-1c50b4aa68dc
# - https://scikit-learn.org/stable/modules/generated/sklearn.tree.plot_tree.html
# - https://stackoverflow.com/questions/46659073/change-numerical-data-to-categorical-data-pandas
# - https://thispointer.com/python-how-to-use-if-else-elif-in-lambda-functions/
# - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.apply.html
# - https://stackoverflow.com/questions/13331698/how-to-apply-a-function-to-two-columns-of-pandas-dataframe
# - https://towardsdatascience.com/scale-standardize-or-normalize-with-scikit-learn-6ccc7d176a02
# - https://towardsdatascience.com/normalization-vs-standardization-quantitative-analysis-a91e8a79cebf
# - https://www.kaggle.com/discdiver/guide-to-scaling-and-standardizing
# - https://scikit-learn.org/stable/auto_examples/preprocessing/plot_all_scaling.html
# - https://sebastianraschka.com/Articles/2014_about_feature_scaling.html
# - https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html
# - https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.CountVectorizer.html
# - https://stackoverflow.com/questions/52410880/is-there-a-way-i-can-initialize-dictionary-values-to-0-in-python-taking-keys-fro
# - https://stackoverflow.com/questions/22257836/numpy-hstack-valueerror-all-the-input-arrays-must-have-same-number-of-dimens
# - https://stackoverflow.com/questions/26576524/how-do-i-transform-a-scipy-sparse-matrix-to-a-numpy-matrix
# - https://docs.scipy.org/doc/numpy/reference/generated/numpy.hstack.html
# - https://www.geeksforgeeks.org/append-extend-python/
# - https://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_auc_score.html
# - https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html
# - https://scikit-learn.org/stable/modules/naive_bayes.html#naive-bayes
# - https://www.tensorflow.org/versions/r1.15/api_docs/python/tf/keras/Input
# - https://machinelearningmastery.com/keras-functional-api-deep-learning/
# - https://github.com/pranaysawant/Zomato-Restaurant-Rate-Prediction/blob/master/Zomato%20Restaurant%20Rating%20Prediction.ipynb
# - https://datascience.stackexchange.com/questions/13490/how-to-set-class-weights-for-imbalanced-classes-in-keras
# - https://datascience.stackexchange.com/questions/45165/how-to-get-accuracy-f1-precision-and-recall-for-a-keras-model
# - https://machinelearningmastery.com/display-deep-learning-model-training-history-in-keras/
# - http://rasbt.github.io/mlxtend/api_subpackages/mlxtend.classifier/
